# %%
# !pip install thefuzz
# !pip install nltk
# !pip install spacy
# !pip install scispacy
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.3/en_core_sci_lg-0.5.3.tar.gz
# !pip install openai
# Out:
# Requirement already satisfied: thefuzz in /usr/local/python/3.10.8/lib/python3.10/site-packages (0.20.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.0.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thefuzz) (3.5.2)
# Requirement already satisfied: nltk in /usr/local/python/3.10.8/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/python/3.10.8/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /usr/local/python/3.10.8/lib/python3.10/site-packages (from nltk) (4.64.0)
# Requirement already satisfied: spacy in /usr/local/python/3.10.8/lib/python3.10/site-packages (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (4.64.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (1.24.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (2.4.2)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: scispacy in /usr/local/python/3.10.8/lib/python3.10/site-packages (0.5.3)
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from scispacy) (3.6.1)
# Requirement already satisfied: scipy<1.11 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from scispacy) (1.10.1)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scispacy) (2.31.0)
# Requirement already satisfied: conllu in /usr/local/python/3.10.8/lib/python3.10/site-packages (from scispacy) (4.5.3)
# Requirement already satisfied: numpy in /usr/local/python/3.10.8/lib/python3.10/site-packages (from scispacy) (1.24.2)
# Requirement already satisfied: joblib in /home/codespace/.local/lib/python3.10/site-packages (from scispacy) (1.3.2)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from scispacy) (2.1.1)
# Requirement already satisfied: scikit-learn>=0.20.3 in /home/codespace/.local/lib/python3.10/site-packages (from scispacy) (1.3.2)
# Requirement already satisfied: pysbd in /usr/local/python/3.10.8/lib/python3.10/site-packages (from scispacy) (0.3.4)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from nmslib>=1.7.3.6->scispacy) (2.6.1)
# Requirement already satisfied: psutil in /home/codespace/.local/lib/python3.10/site-packages (from nmslib>=1.7.3.6->scispacy) (5.9.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.0.0->scispacy) (2023.7.22)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/codespace/.local/lib/python3.10/site-packages (from scikit-learn>=0.20.3->scispacy) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (4.64.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (2.4.2)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.0->scispacy) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->scispacy) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->scispacy) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->scispacy) (4.8.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->scispacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->scispacy) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->scispacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.0->scispacy) (2.1.3)
# Collecting https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.3/en_core_sci_lg-0.5.3.tar.gz
#   Using cached https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.3/en_core_sci_lg-0.5.3.tar.gz (531.2 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: spacy<3.7.0,>=3.6.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from en-core-sci-lg==0.5.3) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (4.64.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (1.24.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.4.2)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (68.0.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (3.3.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/codespace/.local/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (4.8.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.10/site-packages (from jinja2->spacy<3.7.0,>=3.6.1->en-core-sci-lg==0.5.3) (2.1.3)
# Requirement already satisfied: openai in /usr/local/python/3.10.8/lib/python3.10/site-packages (1.2.3)
# Requirement already satisfied: anyio<4,>=3.5.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openai) (0.25.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openai) (2.4.2)
# Requirement already satisfied: tqdm>4 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from openai) (4.64.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /home/codespace/.local/lib/python3.10/site-packages (from openai) (4.8.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<4,>=3.5.0->openai) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /home/codespace/.local/lib/python3.10/site-packages (from anyio<4,>=3.5.0->openai) (1.3.0)
# Requirement already satisfied: exceptiongroup in /home/codespace/.local/lib/python3.10/site-packages (from anyio<4,>=3.5.0->openai) (1.1.3)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Requirement already satisfied: httpcore in /usr/local/python/3.10.8/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.10.1 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.10.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/python/3.10.8/lib/python3.10/site-packages (from httpcore->httpx<1,>=0.23.0->openai) (0.14.0)

# %%
import nltk
from load_data import load_ann, load_txt
import pandas as pd
from thefuzz import fuzz
from nltk.stem import WordNetLemmatizer
import spacy
from scispacy.abbreviation import AbbreviationDetector
from openai import OpenAI
from scipy.spatial.distance import cosine
from scispacy.linking import EntityLinker
# from Bio_Epidemiology_NER.bio_recognizer import ner_prediction


nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

# abreviation_handler = spacy.load("en_core_sci_lg")
# abreviation_handler.add_pipe("abbreviation_detector")


# abreviation_handler = spacy.load("en_core_sci_lg")
# abreviation_handler.add_pipe("abbreviation_detector")

# TODO: Put in config
client = OpenAI(api_key='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')

def get_embedding(text, model="text-embedding-ada-002"):
   text = text.replace("\n", " ")
   returnVal = client.embeddings.create(input = [text], model=model).data[0].embedding
   print(returnVal)
   return returnVal
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
PATH_TO_ZIP = "/workspaces/codespaces-jupyter/Project/RawData"
DATA_PATH = f"{PATH_TO_ZIP}/"
print(f"Full data path: {DATA_PATH}")
# read in txt files
txt_df = load_txt(DATA_PATH)
# read in REASONS entities from .ann files
ent_df, rel_df = load_ann(DATA_PATH)
# Out:
# Full data path: /workspaces/codespaces-jupyter/Project/RawData/
# Time taken to read .txt files: 0.9435818195343018
# Time taken to read .ann files and extract all metadata: 0.1653289794921875

# %%
"""
DATA CLEANING
"""

"""
1. Convert 'text' columns to lowercase, in order to facilitate comparison.
"""
# To lowercase 'text' column in ent_df
ent_df['text'] = ent_df['text'].str.lower()
ent_df['text'] = ent_df['text'].str.strip()

# To lowercase 'text' column in txt_df
# txt_df['text'] = txt_df['text'].str.lower()

"""
2. Remove \n ending from 'text' column in ent_df and in 'entity2' column in rel_df.
"""
ent_df['text'] = ent_df['text'].str.rstrip('\n')
rel_df['entity2'] = rel_df['entity2'].str.rstrip('\n')

"""
3. Convert 'start_idx' and 'end_idx' columns in ent_df to int.
"""
# Drop rows that cannot be converted to int TODO: Make this better
ent_df = ent_df[ent_df['start_idx'].str.isnumeric()]
ent_df = ent_df[ent_df['end_idx'].str.isnumeric()]
ent_df['start_idx'] = ent_df['start_idx'].astype(int)
ent_df['end_idx'] = ent_df['end_idx'].astype(int)

# Make new column with lemmatized text of 'text' column called 'lemmatized_text'
ent_df['orig_txt'] = ent_df['text']
def lemmatize_text(text):
    words = nltk.word_tokenize(text)
    lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(lemmatized_words)

ent_df['text'] = ent_df['text'].apply(lemmatize_text)
# Convert ent_df['text'] to string
ent_df['text'] = ent_df['text'].astype(str)


"""
4. Add definition of abbreviations to 'text' in txt_df
"""
# Loop through each row in txt_df and then use abreviation_handler to find abbreviations and then insert definition in parenthesis after abbreviation, for every abbreviation found in the 'text' column.
# for index, row in txt_df.iterrows():
#     doc = abreviation_handler(row['text'])
#     print(len(doc._.abbreviations))
    # for abrv in doc._.abbreviations:
    #     row['text'] = row['text'].replace(f"{abrv}", f"{abrv} ({abrv._.long_form})")
# Out:
# "\n4. Add definition of abbreviations to 'text' in txt_df\n"

# %%
"""
FEATURE ENGINEERING
"""

"""
1. Join the appropriate entity1 and entity2 for each relation in rel_df.
"""
# Remove first 5 letters from 'entity1' and 'entity2' column in rel_df
rel_df['entity1'] = rel_df['entity1'].str[5:]
rel_df['entity2'] = rel_df['entity2'].str[5:]
rel_df = rel_df.merge(ent_df[['entity_id', 'text', 'file_idx']], how='left', left_on=['entity1', 'file_idx'], right_on=['entity_id', 'file_idx'])
rel_df.rename(columns={'text': 'entity1_text'}, inplace=True)
rel_df = rel_df.merge(ent_df[['entity_id', 'text', 'file_idx']], how='left', left_on=['entity2', 'file_idx'], right_on=['entity_id', 'file_idx'])
rel_df.rename(columns={'text': 'entity2_text'}, inplace=True)
rel_df.drop(columns=['entity_id_x', 'entity_id_y'], inplace=True)

# Create column 'entity1_entity2' in rel_df
rel_df['entity1_entity2'] = rel_df['entity1_text'] + rel_df['entity2_text']

"""
2. Get count of text in file_idx for each entity in ent_df. Do the same for the 'entity1_entity2' in rel_df.
"""
ent_df_count = ent_df.groupby(['text', 'file_idx']).size().reset_index(name='count_in_document')
ent_df = ent_df.merge(ent_df_count, how='left', left_on=['text', 'file_idx'], right_on=['text', 'file_idx'])
rel_df_count = rel_df.groupby(['entity1_entity2', 'file_idx']).size().reset_index(name='count_in_document')
rel_df = rel_df.merge(rel_df_count, how='left', left_on=['entity1_entity2', 'file_idx'], right_on=['entity1_entity2', 'file_idx'])

"""
3. Create encoding to represent if entity in ent_df is in the 'Discharge Diagnosis', 'Chief Complaint', or 'History of Present Illness' section of the txt_df.
"""
def find_section_range(row, section_name):
    lines = row['text'].split('\n')
    matches = [(i, fuzz.ratio(line.lower(), section_name.lower())) for i, line in enumerate(lines)]
    matches.sort(key=lambda x: x[1], reverse=True)  # sort by fuzz.ratio in descending order
    if not matches:
        # Raise error if no match is found
        raise ValueError(f"Could not find section {section_name} in file {row['file_idx']}")
    start_line = matches[0][0]  # start of the range is the line with the highest fuzz.ratio
    end_line = start_line
    while end_line < len(lines) and lines[end_line].strip() != '':
        end_line += 1
    # calculate start and end index within the raw text
    start_index = sum(len(line) + 1 for line in lines[:start_line])  # +1 for the newline character
    end_index = sum(len(line) + 1 for line in lines[:end_line])  # +1 for the newline character
    if row['file_idx'] == '100035':
        # print(row['text'][start_index: start_index + 20], '\n', row['text'][end_index: end_index + 20])
        print(row['text'][10559:10563] )
    return (start_index, end_index)

txt_df['DD_Range'] = txt_df.apply(lambda row: find_section_range(row, 'Discharge Diagnosis'), axis=1)
txt_df['CC_Range'] = txt_df.apply(lambda row: find_section_range(row, 'Chief Complaint'), axis=1)
txt_df['HPI_Range'] = txt_df.apply(lambda row: find_section_range(row, 'History of Present Illness'), axis=1)

# Join the 'DD_Range', 'CC_Range', and 'HPI_Range' columns from txt_df to ent_df
ent_df = ent_df.merge(txt_df[['file_idx', 'DD_Range', 'CC_Range', 'HPI_Range']], how='left', left_on=['file_idx'], right_on=['file_idx'])

# Loop through each entity in ent_df and check if it is in the 'Discharge Diagnosis', 'Chief Complaint', or 'History of Present Illness' section of the txt_df.
# If it is, then add the section name to the 'section' column in ent_df.
def find_section(row):
    # Throw error if start_idx is greater than end_idx
    if row['start_idx'] > row['end_idx']:
        raise ValueError(f"start_idx {row['start_idx']} is greater than end_idx {row['end_idx']}")
    # Throw error if start_idx and end_idx are in multiple sections
    if row['start_idx'] >= row['DD_Range'][0] and row['end_idx'] <= row['DD_Range'][1] and row['start_idx'] >= row['CC_Range'][0] and row['end_idx'] <= row['CC_Range'][1]:
        print(row['file_idx'])
        # raise ValueError(f"start_idx {row['start_idx']} and end_idx {row['end_idx']} are in both DD and CC")
    if row['start_idx'] >= row['DD_Range'][0] and row['end_idx'] <= row['DD_Range'][1] and row['start_idx'] >= row['HPI_Range'][0] and row['end_idx'] <= row['HPI_Range'][1]:
        print(row['file_idx'])
        # raise ValueError(f"start_idx {row['start_idx']} and end_idx {row['end_idx']} are in both DD and HPI")
    if row['start_idx'] >= row['CC_Range'][0] and row['end_idx'] <= row['CC_Range'][1] and row['start_idx'] >= row['HPI_Range'][0] and row['end_idx'] <= row['HPI_Range'][1]:
        print(row['file_idx'])
        # raise ValueError(f"start_idx {row['start_idx']} and end_idx {row['end_idx']} are in both CC and HPI")
    
    # If start_idx and end_idx are in one section, return the section name
    if row['start_idx'] >= row['DD_Range'][0] and row['end_idx'] <= row['DD_Range'][1]:
        return 'Discharge Diagnosis'
    elif row['start_idx'] >= row['CC_Range'][0] and row['end_idx'] <= row['CC_Range'][1]:
        return 'Chief Complaint'
    elif row['start_idx'] >= row['HPI_Range'][0] and row['end_idx'] <= row['HPI_Range'][1]:
        return 'History of Present Illness'
    else:
        return 'Other'

ent_df['section'] = ent_df.apply(lambda row: find_section(row), axis=1)
# Drop DD_Range, CC_Range, and HPI_Range columns from ent_df
ent_df.drop(columns=['DD_Range', 'CC_Range', 'HPI_Range'], inplace=True)
# Apply one hot encoding to 'section' column in ent_df
ent_df = pd.get_dummies(ent_df, columns=['section'])
# Out:
# 75mg
# 75mg
# 75mg
# 106575
# 106575
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 134445
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 111542
# 149687
# 149687
# 149687
# 149687
# 149687
# 149687
# 149687
# 149687
# 149687
# 108949
# 176106
# 176106
# 176106
# 176106
# 176106
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 125867
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 174143
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053
# 102053

# %%
txt_df_subset = txt_df[txt_df['file_idx'] == '100035']
ent_df_subset = ent_df[ent_df['file_idx'] == '100035']
rel_df_subset = rel_df[rel_df['file_idx'] == '100035']

# %%
# # Get DD_Range, CC_Range, and HPI_Range for each file in txt_df_subset and store in tuples
# DD_Range = txt_df_subset['DD_Range'].iloc[0]
# CC_Range = txt_df_subset['CC_Range'].iloc[0]
# HPI_Range = txt_df_subset['HPI_Range'].iloc[0]

# # Create a dict that loops through each line in the txt_df_subset 'text' column in the DD_Range and stores each diagnosis as a key and the value as an embedding of the diagnosis using get_embedding from openai.
# diagnosis_dict = {}
# count_dict = {}
# for line in str(txt_df_subset['text'].iloc[0][DD_Range[0]:DD_Range[1]]).split('\n'):
#     if len(line) > 0:
#         diagnosis_dict[line] = get_embedding(line)
#         count_dict[line] = 0

# curr_text = str(txt_df_subset['text'].iloc[0])
# text_to_analyze = ""
# # Add the text from the CC_Range and HPI_Range to text_to_analyze
# text_to_analyze += curr_text[CC_Range[0]:CC_Range[1]]
# text_to_analyze += curr_text[HPI_Range[0]:HPI_Range[1]]

# # For each sentence in the txt_df_subset 'text' column in the CC_Range and HPI_Range, convert the sentence to an embedding using get_embedding from openai. Get the sentences using nltk
# for line in nltk.sent_tokenize(text_to_analyze):
#     # For each diagnosis in diagnosis_dict, calculate the cosine similarity between the diagnosis embedding and the sentence embedding. Store the diagnosis with the highest cosine similarity in the count_dict.
#     max_sim = 0
#     max_diagnosis = ""
#     for diagnosis, embedding in diagnosis_dict.items():
#         similarity = cosine(embedding, get_embedding(line))
#         if similarity > max_sim:
#             max_diagnosis = diagnosis
#             max_sim = similarity
#     print(max_sim)
#     count_dict[max_diagnosis] += 1

# print(count_dict)

# %%
# nlp = spacy.load("en_core_sci_lg")
# nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})

# diagnosis_dict = {}
# objects = []
# for line in str(txt_df_subset['text'].iloc[0][DD_Range[0]:DD_Range[1]]).split('\n'):
#     if len(line) > 0:
#         doc = nlp(line)
#         linker = nlp.get_pipe("scispacy_linker")
#         for entity in doc.ents:
#             for umls_ent in entity._.kb_ents:
#                 try:
#                     objects.append(linker.kb.cui_to_entity[umls_ent[0]])
#                     break
#                 except:
#                     print("error")
#                 # diagnosis_dict[ent.entity_id] = ent.canonical_name

# %%
# for object in objects:
#     print(object[2])

# %%
df = pd.DataFrame(columns=['file_idx', 'primary_diagnosis', 'count'])  # initialize df as an empty DataFrame
def create_freq_dict(df_input):
    nlp = spacy.load("en_core_sci_lg")
    nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
    linker = nlp.get_pipe("scispacy_linker")

    for i, file_idx in enumerate(txt_df['file_idx'].unique()):
        print(i, " out of ", len(txt_df['file_idx'].unique()))
        txt_df_subset = txt_df[txt_df['file_idx'] == file_idx]

        # Get DD_Range, CC_Range, and HPI_Range for each file in txt_df_subset and store in tuples
        DD_Range = txt_df_subset['DD_Range'].iloc[0]
        CC_Range = txt_df_subset['CC_Range'].iloc[0]
        HPI_Range = txt_df_subset['HPI_Range'].iloc[0]

        # Create a dict that loops through each line in the txt_df_subset 'text' column in the DD_Range and stores each diagnosis as a key and the value as an embedding of the diagnosis using get_embedding from openai.
        diagnosis_dict = {}
        for i, line in enumerate(str(txt_df_subset['text'].iloc[0][DD_Range[0]:DD_Range[1]]).split('\n')):
            if i == 0:
                continue
            if len(line) > 0:
                doc = nlp(line)
                for entity in doc.ents:
                    diagnosis_dict[entity] = []
                    for umls_ent in entity._.kb_ents:
                        try:
                            object = linker.kb.cui_to_entity[umls_ent[0]]
                            for alias in object[2]:
                                diagnosis_dict[entity].append(alias)
                        except Exception as e:
                            print(e)

        count_dict = {}
        for key, _ in diagnosis_dict.items():
            count_dict[key] = 0

        curr_text = str(txt_df_subset['text'].iloc[0])
        # text_to_analyze = ""
        # # Add the text from the CC_Range and HPI_Range to text_to_analyze
        # text_to_analyze += curr_text[CC_Range[0]:CC_Range[1]]
        # text_to_analyze += curr_text[HPI_Range[0]:HPI_Range[1]]

        for line in nltk.sent_tokenize(curr_text):
            doc = nlp(line)
            for entity in doc.ents:
                for umls_ent in entity._.kb_ents:
                    try:
                        object = linker.kb.cui_to_entity[umls_ent[0]]
                        for key, arr in diagnosis_dict.items():
                            for alias in object[2]:
                                if alias in arr:
                                    count_dict[key] += 1
                                    break
                    except Exception as e:
                        print(e)

        for key, value in count_dict.items():
            df_input = df_input.append({'file_idx': file_idx, 'primary_diagnosis': key, 'count': value}, ignore_index=True)

    return df_input

df = create_freq_dict(df)
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/spacy/language.py:2141: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator TfidfTransformer from version 1.1.2 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /home/codespace/.local/lib/python3.10/site-packages/sklearn/base.py:348: InconsistentVersionWarning: Trying to unpickle estimator TfidfVectorizer from version 1.1.2 when using version 1.3.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Save df to csv
df.to_csv('primary_diagnosis.csv', index=False)

# %%
# Get DD_Range, CC_Range, and HPI_Range for each file in txt_df_subset and store in tuples
DD_Range = txt_df_subset['DD_Range'].iloc[0]
CC_Range = txt_df_subset['CC_Range'].iloc[0]
HPI_Range = txt_df_subset['HPI_Range'].iloc[0]

# Create a dict that loops through each line in the txt_df_subset 'text' column in the DD_Range and stores each diagnosis as a key and the value as an embedding of the diagnosis using get_embedding from openai.
nlp = spacy.load("en_core_sci_lg")
nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
diagnosis_dict = {}
for i, line in enumerate(str(txt_df_subset['text'].iloc[0][DD_Range[0]:DD_Range[1]]).split('\n')):
    if i == 0:
        continue
    if len(line) > 0:
        doc = nlp(line)
        linker = nlp.get_pipe("scispacy_linker")
        for entity in doc.ents:
            print(entity)
            diagnosis_dict[entity] = []
            for umls_ent in entity._.kb_ents:
                try:
                    for ent in umls_ent:
                        print(ent)
                    object = linker.kb.cui_to_entity[umls_ent[0]]
                    for alias in object[2]:
                        diagnosis_dict[entity].append(alias)
                except Exception as e:
                    print(e)

print(diagnosis_dict)
count_dict = {}
for key, _ in diagnosis_dict.items():
    count_dict[key] = 0
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /workspaces/codespaces-jupyter/Project/Dataset Creation/dataset_creation.ipynb Cell 11 line 7
#       <a href='vscode-notebook-cell://codespaces%2Bspecial-space-orbit-q9x6v659q5w3r9v/workspaces/codespaces-jupyter/Project/Dataset%20Creation/dataset_creation.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> HPI_Range = txt_df_subset['HPI_Range'].iloc[0]
#       <a href='vscode-notebook-cell://codespaces%2Bspecial-space-orbit-q9x6v659q5w3r9v/workspaces/codespaces-jupyter/Project/Dataset%20Creation/dataset_creation.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> # Create a dict that loops through each line in the txt_df_subset 'text' column in the DD_Range and stores each diagnosis as a key and the value as an embedding of the diagnosis using get_embedding from openai.
# ----> <a href='vscode-notebook-cell://codespaces%2Bspecial-space-orbit-q9x6v659q5w3r9v/workspaces/codespaces-jupyter/Project/Dataset%20Creation/dataset_creation.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> nlp = spacy.load("en_core_sci_lg")
#       <a href='vscode-notebook-cell://codespaces%2Bspecial-space-orbit-q9x6v659q5w3r9v/workspaces/codespaces-jupyter/Project/Dataset%20Creation/dataset_creation.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> nlp.add_pipe("scispacy_linker", config={"resolve_abbreviations": True, "linker_name": "umls"})
#       <a href='vscode-notebook-cell://codespaces%2Bspecial-space-orbit-q9x6v659q5w3r9v/workspaces/codespaces-jupyter/Project/Dataset%20Creation/dataset_creation.ipynb#X12sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> diagnosis_dict = {}
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/__init__.py:51, in load(name, vocab, disable, enable, exclude, config)
#      27 def load(
#      28     name: Union[str, Path],
#      29     *,
#    (...)
#      34     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      35 ) -> Language:
#      36     """Load a spaCy model from an installed package or a local path.
#      37
#      38     name (str): Package name or model path.
#    (...)
#      49     RETURNS (Language): The loaded nlp object.
#      50     """
# ---> 51     return util.load_model(
#      52         name,
#      53         vocab=vocab,
#      54         disable=disable,
#      55         enable=enable,
#      56         exclude=exclude,
#      57         config=config,
#      58     )
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/util.py:465, in load_model(name, vocab, disable, enable, exclude, config)
#     463     return get_lang_class(name.replace("blank:", ""))()
#     464 if is_package(name):  # installed as package
# --> 465     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     466 if Path(name).exists():  # path to model data directory
#     467     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/util.py:501, in load_model_from_package(name, vocab, disable, enable, exclude, config)
#     484 """Load a model from an installed package.
#     485
#     486 name (str): The package name.
#    (...)
#     498 RETURNS (Language): The loaded nlp object.
#     499 """
#     500 cls = importlib.import_module(name)
# --> 501 return cls.load(vocab=vocab, disable=disable, enable=enable, exclude=exclude, config=config)
#
# File ~/.python/current/lib/python3.10/site-packages/en_core_sci_lg/__init__.py:10, in load(**overrides)
#       9 def load(**overrides):
# ---> 10     return load_model_from_init_py(__file__, **overrides)
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/util.py:682, in load_model_from_init_py(init_file, vocab, disable, enable, exclude, config)
#     680 if not model_path.exists():
#     681     raise IOError(Errors.E052.format(path=data_path))
# --> 682 return load_model_from_path(
#     683     data_path,
#     684     vocab=vocab,
#     685     meta=meta,
#     686     disable=disable,
#     687     enable=enable,
#     688     exclude=exclude,
#     689     config=config,
#     690 )
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/util.py:547, in load_model_from_path(model_path, meta, vocab, disable, enable, exclude, config)
#     538 config = load_config(config_path, overrides=overrides)
#     539 nlp = load_model_from_config(
#     540     config,
#     541     vocab=vocab,
#    (...)
#     545     meta=meta,
#     546 )
# --> 547 return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/language.py:2155, in Language.from_disk(self, path, exclude, overrides)
#    2152 if not (path / "vocab").exists() and "vocab" not in exclude:  # type: ignore[operator]
#    2153     # Convert to list here in case exclude is (default) tuple
#    2154     exclude = list(exclude) + ["vocab"]
# -> 2155 util.from_disk(path, deserializers, exclude)  # type: ignore[arg-type]
#    2156 self._path = path  # type: ignore[assignment]
#    2157 self._link_components()
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/util.py:1392, in from_disk(path, readers, exclude)
#    1389 for key, reader in readers.items():
#    1390     # Split to support file names like meta.json
#    1391     if key.split(".")[0] not in exclude:
# -> 1392         reader(path / key)
#    1393 return path
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/language.py:2131, in Language.from_disk.<locals>.deserialize_vocab(path)
#    2129 def deserialize_vocab(path: Path) -> None:
#    2130     if path.exists():
# -> 2131         self.vocab.from_disk(path, exclude=exclude)
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/vocab.pyx:504, in spacy.vocab.Vocab.from_disk()
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/vectors.pyx:647, in spacy.vectors.Vectors.from_disk()
#
# File ~/.python/current/lib/python3.10/site-packages/spacy/util.py:1383, in from_disk(path, readers, exclude)
#    1379             writer(path / key)
#    1380     return path
# -> 1383 def from_disk(
#    1384     path: Union[str, Path],
#    1385     readers: Dict[str, Callable[[Path], None]],
#    1386     exclude: Iterable[str],
#    1387 ) -> Path:
#    1388     path = ensure_path(path)
#    1389     for key, reader in readers.items():
#    1390         # Split to support file names like meta.json
#
# KeyboardInterrupt:

# %%
for key, _ in diagnosis_dict.items():
    count_dict[key] = 0
curr_text = str(txt_df_subset['text'].iloc[0])
# text_to_analyze = ""
# # Add the text from the CC_Range and HPI_Range to text_to_analyze
# text_to_analyze += curr_text[CC_Range[0]:CC_Range[1]]
# text_to_analyze += curr_text[HPI_Range[0]:HPI_Range[1]]

for line in nltk.sent_tokenize(curr_text):
    doc = nlp(line)
    linker = nlp.get_pipe("scispacy_linker")
    for entity in doc.ents:
        for umls_ent in entity._.kb_ents:
            try:
                object = linker.kb.cui_to_entity[umls_ent[0]]
                print(object[2])
                for key, arr in diagnosis_dict.items():
                    for alias in object[2]:
                        if alias in arr:
                            count_dict[key] += 1
                            break
            except Exception as e:
                print(e)
# Out:
# ['Chief Complaint', 'Primary Complaint', 'Presenting complaint', '{Chief complaint}', 'Chief complaint', 'Presenting Complaint', 'Chief complaint (finding)', 'Main Complain', 'chief complaint']
# ['Other Chief Complaint']
# ['Chief complaint duration', 'Duration of Chief Complaint']
# []
# []
# ['Post Cardiac Arrest Syndrome', 'Postresuscitation Disease', 'Postresuscitation Diseases', 'Post-Cardiac Arrest Syndromes', 'Postcardiac Arrest Syndromes', 'Postcardiac Arrest Syndrome']
# ['arrest [as an cardiac arrest]', 'Cardiac arrest (disorder)', 'ARREST CARDIAC', 'Cardiac arrest- asystole', 'arrest', 'cardiac arrest', 'CARDIAC ASYSTOLE', 'ASYSTOLIA', 'Asystole (disorder)', 'ventricular asystole', 'Asystole', 'VENTRICULAR ASYSTOLIA', 'cardiac asystole', 'Heart Arrest', 'Arrest, Heart', 'asystolia', 'Arrest, Cardiac', 'SCA', 'Cardiac Arrest', 'Cardiac arrest', 'asystole', 'Heart stops beating', 'heart arrest', 'Asystoles', 'STANDSTILL CARDIAC', 'Cardiac standstill', 'ASYSTOLE', 'HEART ARREST', 'arrested', 'CARDIAC ARREST']
# ['acute asthma exacerbation', 'exacerbation of asthma', 'of asthma exacerbation', 'exacerbation asthma', 'Exacerbation of asthma (disorder)', 'Acute asthma', 'asthma exacerbation', 'asthma exacerbations', 'Exacerbation of asthma', 'Asthma attack', 'acute exacerbation of asthma']
# ['status asthmaticus', 'asthma asthmaticus status', 'asthmaticus status', 'Asthma, unspecified type, with status asthmaticus', 'STATUS ASTHMATICUS', 'Asthmatic Crises', 'Shock, Asthmatic', 'Status Asthmaticus', 'Asthmatic Shocks', 'Shocks, Asthmatic', 'Asthmatic Crisis', 'Status asthmaticus', 'Asthma with status asthmaticus', 'Asthmatic Shock', 'severe acute asthma', 'acute severe asthma', 'Acute severe exacerbation of asthma', 'Asthmaticus, Status', 'Acute severe exacerbation of asthma (disorder)', 'Crisis, Asthmatic', 'asthmatic crisis', 'Crises, Asthmatic', 'Acute severe asthma']
# []
# ['ho', 'hos', 'History of present illness', 'HISTORY OF PRESENT ILLNESS', 'hpi', 'history']
# ['Hx of Pres illness', 'Present illness:History:To identify measures at a point in time:^Patient:Nominal', 'Present illness:Hx:Pt:^Patient:Nom', 'History of Present illness']
# ['year', 'Year', 'Annum', 'years', 'yr', 'year (qualifier value)']
# ['year']
# ['year']
# ['/year', 'per year', 'Per Year', 'per year (qualifier value)', 'per years', 'Yearly']
# []
# ['asthmatics', 'asthmatic', 'ASTHMA', 'Bronchial asthma, NOS', 'Asthma', 'Asthma, Bronchial', 'Airway hyperreactivity', 'ASTHMA BRONCHIAL', 'ASTHMA, BRONCHIAL', 'Asthma, unspecified', 'asthma disorders', 'br asthma', 'Asthmas', 'Bronchial Asthma', 'Asthmatic', 'Bronchial asthma', 'asthma', 'Asthma (disorder)', 'Asthma, NOS', 'BRONCHIAL ASTHMA', 'bronchial asthma', 'bronchitic asthma']
# ['status asthmaticus', 'asthma asthmaticus status', 'asthmaticus status', 'Asthma, unspecified type, with status asthmaticus', 'STATUS ASTHMATICUS', 'Asthmatic Crises', 'Shock, Asthmatic', 'Status Asthmaticus', 'Asthmatic Shocks', 'Shocks, Asthmatic', 'Asthmatic Crisis', 'Status asthmaticus', 'Asthma with status asthmaticus', 'Asthmatic Shock', 'severe acute asthma', 'acute severe asthma', 'Acute severe exacerbation of asthma', 'Asthmaticus, Status', 'Acute severe exacerbation of asthma (disorder)', 'Crisis, Asthmatic', 'asthmatic crisis', 'Crises, Asthmatic', 'Acute severe asthma']
# ['Systemic hypertension', 'systemic hypertension', 'Hypertensive disorder', 'Arterial hypertension', 'Hypertension', 'Hypertensive vascular degeneration', 'Vascular Hypertensive Disorder', 'Hypertensive disease, NOS', 'hypertension', 'Blood Pressures, High', 'Hypertension, arterial', 'HT - Hypertension', 'hypertensive disorder', 'Blood Pressure, High', 'Hypertension (high blood pressure)', 'Hypertension, NOS', 'high bp', 'BLOOD PRESSURE HIGH', 'HTN - Hypertension', 'HYPERTENSION ARTERIAL', 'high blood pressure disorder', 'systemic arterial hypertension', 'BP+ - Hypertension', 'HYPERTENSION', 'Hyperpiesis', 'Hypertensive vascular disease', 'HBP', 'High blood pressure disorder', 'htn', 'Elevated blood pressure', 'hbp', 'Hypertensive cardiovascular disease or syndrome', 'BP - High blood pressure', 'hyperpiesis', 'vascular hypertension', 'HBP - High blood pressure', 'arterial hypertension', 'high blood pressure', 'vascular hypertensive disorder', 'arterial hypertension systemic', 'HTN', 'Hyperpiesia', 'hyperpiesia', 'Hypertensive disorder, systemic arterial (disorder)', 'High Blood Pressures', 'HYPERTENSIVE DISEASES', 'High blood pressure', 'High Blood Pressure', 'Systemic arterial hypertension', 'hypertensive disease', 'Hypertensive disorder, systemic arterial', 'hypertensive vascular disease', 'blood high pressure', 'Complications affecting other specified body systems, not elsewhere classified, hypertension', 'HYPERTENSIVE DISEASE']
# ['dia htn', 'Diastolic Hypertension', 'BLOOD PRESSURE INCREASE DIASTOLIC', 'HYPERTENSION DIASTOLIC', 'diastolic hypertension', 'dia hypertension', 'DIASTOLIC HYPERTENSION', 'diastolic htn', 'Diastolic hypertension (disorder)', 'Hypertension, diastolic', 'Diastolic hypertension, NOS']
# ['Hypertension, systolic', 'systolic htn', 'Systolic hypertension (disorder)', 'sys hypertension', 'SYSTOLIC HYPERTENSION', 'Systolic Hypertension', 'Systolic Hypertensions', 'Hypertension, Systolic', 'systolic hypertension', 'sys htn', 'Systolic hypertension']
# ['Clinic Hypertension, Isolated', 'Hypertension, Isolated Clinic', 'labile hypertension', 'white coat hypertension', 'coat hypertension white', 'White Coat Hypertension', 'Isolated Clinic Hypertension', 'labile htn', 'White Coat Syndrome', 'Hypertension, White Coat', 'Labile hypertension due to being in a clinical environment', 'Syndrome, White Coat', 'Labile hypertension due to being in a clinical environment (disorder)', 'White coat hypertension', 'hypertension white coat']
# ['CHTN']
# ['Admission to hospital', 'hospital admission', 'Hospital admission, NOS', 'HOSPITAL ADMISSIONS', 'admit', 'Hospital Admission', 'Admission', 'Admit', 'admitted hospital', 'admission to hospital', 'Hospital admission', 'Hospital Admissions', 'admission hospital', 'hospital admissions', 'admissions hospital', 'admissions', 'admission', 'Hospital admission (procedure)', 'admitted', 'admits', 'admitting']
# ['Admission', 'Admitted']
# []
# ['DOSH', '10-deoxysarpagine,NADPH:oxygen oxidoreductase (10-hydroxylating) activity']
# ['Dyspnea, NOS', 'BREATHLESSNESS', 'Difficulty breathing', 'Breathless', 'Dyspnoea', 'SHORTNESS OF BREATH', 'difficult breathing', 'Breath Shortness', 'BREATHING DIFFICULT', 'Shortness of breath dyspnea', 'sob', 'breathing difficulty', 'breathing shortness', 'shortness of breath', 'DIFFICULTY BREATHING', 'DYSPNEA', 'SOB - Shortness of breath', 'Breathlessness', 'breath shortness', 'SOB', 'respiratory difficulty', 'Shortness of Breath', 'shortness of breath (SOB)', 'BREATH SHORTNESS', 'Breathing difficulties', 'Dyspnea (finding)', 'SOB (SHORTNESS OF BREATH)', 'dyspnoea', 'Trouble breathing', 'Respiration difficult', 'DIB - Difficulty in breathing', 'breathlessness', 'tightness of breath', 'DYSPNOEA', 'breathing difficulties', 'dyspnea', 'Shortness of breath', 'Abnormal breathing', 'Dyspnea', 's.o.b.', 'breathless', 'Respiratory difficulties', 'Dyspnoea, NOS', 'Breathing difficulty', 'Difficulty breathing (finding)', 'Difficult to breathe']
# ['shortness of breath at rest', 'Rest Dyspnea', 'Shortness of breath at rest', 'Dyspneas, Rest', 'Dyspnea, Rest', 'Dyspnea at rest (finding)', 'shortness of breath rest', 'Dyspnoea at rest', 'Breathless - at rest', 'Dyspnea at rest', 'Dyspnea At Rest', 'Rest dyspnea', 'Dyspnea resting', 'breath rest shortness', 'Dyspnea^resting', 'Breathlessness at rest', 'SOBAR - Shortness of breath at rest']
# []
# []
# ['Shortness of breathing upon physical activity', 'Dyspnea on exertion', 'exertional dyspnoea', 'Dyspnea on effort', 'Dyspnoea on exertion', 'exertional dyspnea', 'Breathlessness on exertion', 'SOBOE - Shortness of breath on exertion', 'Exertional dyspnoea', 'doe', 'DYSPNEA, EXERTIONAL', 'Exertional breathlessness', 'exertion dyspnea', 'SHORTNESS OF BREATH (ON EXERTION)', 'Short of breath on exertion', 'DOE', 'Dyspnea on exertion (finding)', 'dyspnea on exertion', 'shortness of breath on exertion', 'shortness of breath during exercise', 'Dyspnea Exertional', 'dyspnea on exertion (DOE)', 'dyspnea exertional', 'Exertional dyspnea', 'Dyspnoea on effort', 'Dyspnea, exertional', 'short of breath on exertion', 'DYSPNEA (ON EXERTION)']
# ['Admission to hospital', 'hospital admission', 'Hospital admission, NOS', 'HOSPITAL ADMISSIONS', 'admit', 'Hospital Admission', 'Admission', 'Admit', 'admitted hospital', 'admission to hospital', 'Hospital admission', 'Hospital Admissions', 'admission hospital', 'hospital admissions', 'admissions hospital', 'admissions', 'admission', 'Hospital admission (procedure)', 'admitted', 'admits', 'admitting']
# ['Admission', 'Admitted']
# []
# ['Peas', 'Pea (substance)', 'peas', 'Pea', 'pea']
# ['electromechanical dissociation', 'Cardiac arrest with electromechanical dissociation', 'Electromechanical Dissociation by ECG Finding', 'Pulseless Electrical Activity', 'PEA - Pulseless electrical activity', 'emd', 'EMD', 'electromechanical dissociation (EMD)', 'Electro-Mechanical Dissociation', 'Electromechanical Dissociation by EKG Finding', 'Pulseless electrical activity', 'Electromechanical dissociation', 'PEA', 'pulseless electrical activity', 'Electromechanical dissociation (disorder)', 'Electromechanical Dissociation']
# ['garden pea', 'peas', 'Pisum sativum', 'sativum, Pisum', 'pea', 'pisum sativum']
# ['PEA']
# ['Pisum sativum allergenic extract', 'PEA', 'Pea', 'pea allergenic extract']
# ['arrest [as an cardiac arrest]', 'Cardiac arrest (disorder)', 'ARREST CARDIAC', 'Cardiac arrest- asystole', 'arrest', 'cardiac arrest', 'CARDIAC ASYSTOLE', 'ASYSTOLIA', 'Asystole (disorder)', 'ventricular asystole', 'Asystole', 'VENTRICULAR ASYSTOLIA', 'cardiac asystole', 'Heart Arrest', 'Arrest, Heart', 'asystolia', 'Arrest, Cardiac', 'SCA', 'Cardiac Arrest', 'Cardiac arrest', 'asystole', 'Heart stops beating', 'heart arrest', 'Asystoles', 'STANDSTILL CARDIAC', 'Cardiac standstill', 'ASYSTOLE', 'HEART ARREST', 'arrested', 'CARDIAC ARREST']
# ['Arrested', 'Arrest', 'Arrested (qualifier value)', 'Arresting']
# ['arrest', 'legal arrest', 'arrests', 'arresting']
# ['Arrester']
# ['S-Antigen, Retinal', 'Arrestin', 'Retinal S-Antigen', 'S Antigen, Retinal', 'Retinal S Antigen', 'arrestin']
# ['patients', 'patient', 'Patient', 'Patient (person)', '*^patient', '^Patient', 'Patients']
# ['Patient']
# ['Patient']
# ['Patient']
# ['Patient']
# ['PIM Kinase Inhibitor LGH447', 'LGH 447', 'LGH447', 'PIM447', 'PIM-447', 'PIM 447', 'LGH-447', 'PIM kinase inhibitor LGH447']
# ['Male Impotence', 'Impotence, Male Sexual', 'Sexual Impotence, Male', 'male erectile disorder', 'Sexual impotence, NOS', 'dysfunctioning erectile', 'Difficulty getting an erection', 'Difficulty getting a full erection', 'Impotence', 'Erectile dysfunction (disorder)', 'erection dysfunction', 'Male Erectile Disorder', 'Erectile dysfunction', 'Erectile Dysfunction', 'Erectile abnormalities', 'Male erectile disorder', 'dysfunction erection', 'sexual impotence', 'erectile dysfunctions', 'Male Sexual Impotence', 'Failure of erection', 'impotent', 'dysfunction erectile', 'PENILE ERECTION IMPAIRMENT', 'impotence', 'Impotent', 'Abnormal erection', 'IMPOTENCE', 'Impotence, Male', 'Dysfunction, Erectile', 'Impotence, NOS', 'Sexual impotence', 'ED', 'erectile dysfunction']
# ['Emergency (DEEDS)', 'Emergency Department (DEEDS) variables', 'ED']
# ['hypoxaemia', 'Arterial hypoxemia', 'Low blood oxygen level', 'Blood oxygen decreased', 'Arterial hypoxaemia', 'Hypoxaemia', 'arterial hypoxemia', 'HYPOXEMIA', 'hypoxemia', 'arterial hypoxaemia', 'Hypoxemia (disorder)', 'hypoxemias', 'Hypoxemia', 'HYPOXAEMIA']
# []
# []
# ['Proxemic']
# ['RESPIRATORY DISTRESS', 'respiratory distress', 'Labored breathing', 'DISTRESS RESPIRATORY', 'Breathing difficulties', 'Respiratory difficulties', 'Respiratory Distress', 'Distressed respiration', 'Respiratory distress', 'Distressed breathing', 'distressed breathing', 'Respiratory distress (finding)', 'distressed respiratory']
# ['acute respiratory distress', 'Acute Respiratory Distress', 'Acute respiratory distress (finding)', 'acute distress respiratory', 'Acute respiratory distress']
# ['Perinatal respiratory distress, NOS']
# ['Neonatal respiratory distress', 'Respiratory distress (newborn)', 'Infantile respiratory distress', 'distress respiratory neonatal', 'Respiratory distress, neonatal', 'neonatal respiratory distress', 'Neonatal respiratory distress (finding)', 'Newborn respiratory distress']
# ['RESPIRATORY DISTRESS SYNDROME NEWBORN', 'distress respiratory syndrome', 'Idiopathic respiratory distress syndrome, NOS', 'infant respiratory distress syndrome', 'Hyaline membrane disease', 'Pulmonary hypoperfusion syndrome of newborn', 'Infant ARDS', 'Neonatal Respiratory Distress Syndrome', 'Newborn Respiratory Distress Syndrome', 'Respiratory Distress Syndrome, Infant', 'Congenital alveolar dysplasia', 'distress respiratory syndromes', 'Respiratory distress syndrome in the newborn (disorder)', 'newborn rds', 'Neonatal respiratory distress syndrome', 'RESPIRATORY DISTRESS SYNDROME, IDIOPATHIC', 'Respiratory distress syndrome of newborn', 'Cardiorespiratory distress syndrome of newborn', 'Wet lung disease of newborn', 'Respiratory distress syndrome in neonate', 'respiratory syndrome distress', 'Idiopathic respiratory distress syndrome of newborn', 'Respiratory distress syndrome in newborn', 'Infant acute respiratory distress syndrome', 'IRDS of newborn', 'SURFACTANT DEFICIENCY SYNDROME NEONATAL', 'Respiratory distress syndrome in the newborn', 'Idiopathic respiratory distress syndrome [IRDS or RDS] of newborn', 'RESPIRATORY DISTRESS SYNDROME, NEONATAL', 'Respiratory Distress Syndrome, Newborn', 'Idiopathic respiratory distress syndrome', 'Infant respiratory distress syndrome', 'Respiratory Distress Syndrome', 'DISTRESS RESPIRATORY SYNDROME NEWBORN', 'idiopathic respiratory distress of newborn', 'IRDS - Idiopathic respiratory distress syndrome', 'Infantile Respiratory Distress Syndrome', 'newborns rds', 'respiratory distress syndrome of newborn', 'RDS of newborn', 'SYNDROME RESPIRATORY DISTRESS NEWBORN', 'RDS, type I', 'RESPIRATORY DISTRESS SYNDROME, PERINATAL', 'respiratory distress syndrome', 'RESP DISTRESS SYNDROME NEONATAL']
# ['DOSH', '10-deoxysarpagine,NADPH:oxygen oxidoreductase (10-hydroxylating) activity']
# ['cyclophosphane', 'cyts', 'N,N-bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxazaphosphorin-2-amine 2-Oxide', '(RS)-Cyclophosphamide', '(+-)-Cyclophosphamide', 'Cyclophosphamide-containing product', 'Mitoxan', 'Cyclophospham', 'Cyclophosphane', 'Cyclophosphanum', 'CTX', 'Cyclophosphan', 'cyclophosphamide', '2H-1,3,2-oxazaphosphorin-2-amine, N,N-is(2-chloroethyl)tetrahydro-,2-oxide, monohydrate', 'Cyclophosphamide (substance)', 'CYT', 'Cyclophosphamide', '2-[Bis(2-chloroethylamino)]-tetrahydro-2H-1,3,2-oxazaphosphorine-2-oxide', 'Claphene', 'cyt', 'CPM', 'Ciclofosfamide', 'N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxazaphosphorin-2-amine 2-oxide', 'Cyclophosphamidum', 'Cytophosphane', '(-)-cyclophosphamide', 'Cyclophosphamid', '2H-1,3,2-oxazaphosphorin-2-amine, N,N-is(2-chloroethyl)tetrahydro-,2-oxide', 'Bis(2-chloroethyl)phosphoramide cyclic propanolamide ester', 'CYCLOPHOSPHAMIDE', 'Product containing cyclophosphamide (medicinal product)', 'Ciclofosfamida', 'N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxazaphosphorin-2-amine 2-Oxide', 'Syklofosfamid']
# ['Cerebrotendinous Xanthomatoses', 'Van Bogaert Scherer Epstein Disease', 'Cerebral cholesterinosis', 'Xanthomatoses, Cerebrotendinous', 'Cerebrotendinous Xanthomatosis', 'Van Bogaert-Scherer-Epstein Disease', 'CTX - Cerebrotendinous xanthomatosis', 'Cholestanolosis', 'CTX', 'CEREBROTENDINOUS XANTHOMATOSIS', 'Van Bogaert-Scherer-Epstein disease', 'CEREBRAL CHOLESTERINOSIS', 'Cerebrotendinous xanthomatosis syndrome', 'VON BOGAERT DISEASE', 'Bogaert-Scherer-Epstein Disease, Van', 'Cerebrotendinous cholesterinosis', 'Cerebrotendinous xanthomatosis', 'Cholestanol storage disease (disorder)', 'cerebrotendinous xanthomatosis', 'Cerebral Cholesterinoses', 'Disease, Van Bogaert-Scherer-Epstein', 'van Bogaert-Scherer-Epstein syndrome', 'Cerebral Cholesterinosis', 'Cholestanol storage disease', 'Xanthomatosis, Cerebrotendinous', 'Sterol 27-hydroxylase deficiency']
# ['CP27', 'cerebrotendinous xanthomatosis', 'CTX', 'CYP27A1 Gene', 'CYP27', 'cytochrome P450 family 27 subfamily A member 1', 'CYP27A1', 'CYTOCHROME P450, SUBFAMILY XXVIIA, POLYPEPTIDE 1', 'cytochrome P450, family 27, subfamily A, polypeptide 1', 'CYP27A1 gene', 'STEROL 27-HYDROXYLASE', 'cytochrome P450, subfamily XXVIIA (steroid 27-hydroxylase, cerebrotendinous xanthomatosis), polypeptide 1', 'Cytochrome P450, Family 27, Subfamily A, Polypeptide 1 Gene']
# ['CP27', 'CTX', 'CYP27', 'Cytochrome P450, Family 27, Subfamily A, Polypeptide 1 wt Allele', 'CYP27A1 wt Allele']
# ['C-Terminal Telopeptide Type 1 Collagen', 'C-Telopeptide', 'CTX', 'Collagen Type 1 Cross-linked C-Telopeptide', 'Cross-Linked C-Terminal Telopeptide of Type I Collagen', 'C-Terminal Telopeptide Type I Collagen', 'CTX-I', 'CTXI']
# ['Product containing azithromycin (medicinal product)', 'Azithromycin', '(2R,3S,4R,5R,8R,10R,11R,12S,13S,14R)-13-[(2,6-Dideoxy-3-C-methyl-3-O-methyl-alpha-L-ribo-hexopyranosyl)oxy]-2-ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-11-[(3,4,6-trideoxy-3-(dimethylamino)-beta-D-xylo-hexopyranosyl]oxy]-1-oxa-6-azacyclopentade', 'Azithromycin (substance)', '(2R,3S,4R,5R,8R,10R,11R,12S,13S,14R)-13-[(2,6-Dideoxy-3-C-methyl-3-O-methyl-alpha-L-ribo-hexopyranosyl)oxy]-2-ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-11-[(3,4,6-trideoxy-3-(dimethylamino)-beta-D-xylo-hexopyranosyl)oxy]-1-oxa-6-azacyclopentade', 'Azithromycine', 'AZITHROMYCIN', 'Azithromycin-containing product', '1-Oxa-6-azacyclopentadecan-15-one, 13-((2,6-dideoxy-3-C-methyl-3-O-methyl-alpha-L-ribo-hexopyranosyl)oxy)-2-ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-11-((3,4,6-trideoxy-3-(dimethylamino)-beta-D-xylo-hexopyranosyl)oxy)-, (2R-(2R*,3S*,4R*,5R*,8R*,10R*,11R*,12S*,13S*,14R*))-', 'N-methyl-11-aza-10-deoxy-10-dihydroerythromycin A', 'Azithromycinum', 'azythromycin', 'azithromycin', 'Azitromicina', 'Azythromycin']
# ['azithromycin dihydrate', 'Azithromycin dihydrate', 'Azithromycin dihydrate (substance)', 'Azithromycin Dihydrate', 'AZITHROMYCIN DIHYDRATE', 'Dihydrate, Azithromycin']
# ['South Carolina', 'SC', 'South Carolina (geographic location)', 'south carolina', 'carolina south']
# ['SC', 'BLOOD GROUP--SCIANNA SYSTEM', 'Scianna blood group system (qualifier value)', 'ISBT system 013', 'ISBT system SC', 'SCIANNA BLOOD GROUP', 'Scianna blood group system']
# ['SC', 'ERYTHROID MEMBRANE-ASSOCIATED PROTEIN', 'ERMAP', 'Radin blood group', 'erythroblast membrane associated protein (Scianna blood group)', 'erythroblast membrane-associated protein (Scianna blood group)', 'ERYTHROCYTE MEMBRANE-ASSOCIATED PROTEIN', 'ERMAP gene', 'erythroblast membrane-associated protein (RD and SC blood groups)', 'Scianna blood group', 'RD', 'BTN5', 'ERYTHROBLAST MEMBRANE-ASSOCIATED PROTEIN', 'erythroblast membrane-associated protein']
# ['subcutaneous drug administration', 'Subcutaneous Route of Administration', 'SubcutaneousRoute', 'Subcutaneous route', 'Subcutaneous route (qualifier value)', 'SC use', 'Subcutaneous (intended site)', 'SC route', 'Subcutaneous use', 'Subcutaneous', 'Subdermal route']
# ['(-)-(R)-epinephrine', 'Product containing epinephrine (medicinal product)', '4-(1-Hydroxy-2-(methylamino)ethyl)-1,2-benzenediol', 'Epinephrinum', 'Therapeutic Epinephrine', 'epi', '(R)-(-)-adrenaline', 'therapeutic epinephrine', 'Adrenaline preparation', '(R)-(-)-Adnephrine', 'Adrenaline', 'Epinephrine', 'epinephrine', '(-)-3,4-dihydroxy-α-((methylamino)methyl)benzyl alcohol', '1,2-Benzenediol, 4-(1-hydroxy-2-(methylamino)ethyl)-, (R)-', 'Adrenaline-containing product', '(R)-(-)-Epinephrine', '(R)-(-)-Adrenaline', '(R)-(-)-Epirenamine', 'adrenalin', 'Adrenalin', 'Epinefrin', 'EPINEPHrine', 'adrenaline', 'EPINEPHRINE', 'Epinephrine-containing product', 'Adrénaline', '4-[(1R)-1-Hydroxy-2-(methylamino)ethyl]-1,2-benzenediol', 'Epinefrina', 'Epinephrine (substance)', 'Epinephrine preparation', 'Epinephrin']
# ['adrenaline binding']
# ['Epinephrine racemic', 'EPINEPHRINE,RACEMIC', 'Adrenaline, Racemic', 'epinephrine racemic', 'Epinephrine, Racemic Mixture', 'Racemic Adrenaline', 'Racemic Epinephrine', 'dl-Epinephrine', 'Epinephrine, Racemic', 'racepinephrine', 'Racemic Mixture Adrenaline', 'racemic epinephrine', 'Racepinephrine (substance)', 'dl-Adrenaline', 'Racemic Mixture Epinephrine', 'RACEPINEPHRINE', 'Racepinephrine', 'Adrenaline, Racemic Mixture', 'Adrenaline racemic']
# ['epinephrine formation', 'epinephrine anabolism', 'adrenaline biosynthesis', 'epinephrine synthesis', 'epinephrine biosynthesis', 'adrenaline biosynthetic process']
# ['Epinephrine measurement', 'Adrenaline measurement', 'Epinephrine Measurement', 'Epinephrine measurement, NOS', 'Epinephrine measurement (procedure)', 'Adrenaline level', 'Adrenaline Measurement', 'ephinephrine level test', 'Epinephrine level']
# ['solu medrol', 'solumedrol', 'Solu-Medrol', 'SOLU-Medrol', 'Solumedrol', 'solu-medrol']
# ['DOSH', '10-deoxysarpagine,NADPH:oxygen oxidoreductase (10-hydroxylating) activity']
# ['Episode', 'Episode (attribute)', 'episode', 'Episodes', 'Episode of', 'Episodes (qualifier value)', 'episodes']
# ['Episode, Patient Care', 'Patient Care Episode', 'Episode of care', 'Care Episodes', 'Episodes, Patient Care', 'Episodes of Care', 'Care Episode', 'Patient Care Episodes', 'episodes of care', 'episode of care']
# ['Recent', 'Recent (qualifier value)', 'Recent episode (qualifier value)', 'recent', 'Recent episode', 'Recently']
# ['Episodic', 'Now and then', 'Episodic (qualifier value)', 'Recurrent']
# ['Peas', 'Pea (substance)', 'peas', 'Pea', 'pea']
# ['electromechanical dissociation', 'Cardiac arrest with electromechanical dissociation', 'Electromechanical Dissociation by ECG Finding', 'Pulseless Electrical Activity', 'PEA - Pulseless electrical activity', 'emd', 'EMD', 'electromechanical dissociation (EMD)', 'Electro-Mechanical Dissociation', 'Electromechanical Dissociation by EKG Finding', 'Pulseless electrical activity', 'Electromechanical dissociation', 'PEA', 'pulseless electrical activity', 'Electromechanical dissociation (disorder)', 'Electromechanical Dissociation']
# ['garden pea', 'peas', 'Pisum sativum', 'sativum, Pisum', 'pea', 'pisum sativum']
# ['PEA']
# ['Pisum sativum allergenic extract', 'PEA', 'Pea', 'pea allergenic extract']
# ['arrest [as an cardiac arrest]', 'Cardiac arrest (disorder)', 'ARREST CARDIAC', 'Cardiac arrest- asystole', 'arrest', 'cardiac arrest', 'CARDIAC ASYSTOLE', 'ASYSTOLIA', 'Asystole (disorder)', 'ventricular asystole', 'Asystole', 'VENTRICULAR ASYSTOLIA', 'cardiac asystole', 'Heart Arrest', 'Arrest, Heart', 'asystolia', 'Arrest, Cardiac', 'SCA', 'Cardiac Arrest', 'Cardiac arrest', 'asystole', 'Heart stops beating', 'heart arrest', 'Asystoles', 'STANDSTILL CARDIAC', 'Cardiac standstill', 'ASYSTOLE', 'HEART ARREST', 'arrested', 'CARDIAC ARREST']
# ['Arrested', 'Arrest', 'Arrested (qualifier value)', 'Arresting']
# ['arrest', 'legal arrest', 'arrests', 'arresting']
# ['Arrester']
# ['S-Antigen, Retinal', 'Arrestin', 'Retinal S-Antigen', 'S Antigen, Retinal', 'Retinal S Antigen', 'arrestin']
# []
# ['intubation', 'Intubation', 'Intubation (procedure)', 'Intubations', 'intubation procedures', 'intubation procedure', 'INTUBATION', 'Intubation Procedure', 'Intubation, NOS', 'intubations', 'Intubation - action', 'Intubation - action (qualifier value)']
# ['(-)-(R)-epinephrine', 'Product containing epinephrine (medicinal product)', '4-(1-Hydroxy-2-(methylamino)ethyl)-1,2-benzenediol', 'Epinephrinum', 'Therapeutic Epinephrine', 'epi', '(R)-(-)-adrenaline', 'therapeutic epinephrine', 'Adrenaline preparation', '(R)-(-)-Adnephrine', 'Adrenaline', 'Epinephrine', 'epinephrine', '(-)-3,4-dihydroxy-α-((methylamino)methyl)benzyl alcohol', '1,2-Benzenediol, 4-(1-hydroxy-2-(methylamino)ethyl)-, (R)-', 'Adrenaline-containing product', '(R)-(-)-Epinephrine', '(R)-(-)-Adrenaline', '(R)-(-)-Epirenamine', 'adrenalin', 'Adrenalin', 'Epinefrin', 'EPINEPHrine', 'adrenaline', 'EPINEPHRINE', 'Epinephrine-containing product', 'Adrénaline', '4-[(1R)-1-Hydroxy-2-(methylamino)ethyl]-1,2-benzenediol', 'Epinefrina', 'Epinephrine (substance)', 'Epinephrine preparation', 'Epinephrin']
# ['adrenaline binding']
# ['Epinephrine racemic', 'EPINEPHRINE,RACEMIC', 'Adrenaline, Racemic', 'epinephrine racemic', 'Epinephrine, Racemic Mixture', 'Racemic Adrenaline', 'Racemic Epinephrine', 'dl-Epinephrine', 'Epinephrine, Racemic', 'racepinephrine', 'Racemic Mixture Adrenaline', 'racemic epinephrine', 'Racepinephrine (substance)', 'dl-Adrenaline', 'Racemic Mixture Epinephrine', 'RACEPINEPHRINE', 'Racepinephrine', 'Adrenaline, Racemic Mixture', 'Adrenaline racemic']
# ['epinephrine formation', 'epinephrine anabolism', 'adrenaline biosynthesis', 'epinephrine synthesis', 'epinephrine biosynthesis', 'adrenaline biosynthetic process']
# ['Epinephrine measurement', 'Adrenaline measurement', 'Epinephrine Measurement', 'Epinephrine measurement, NOS', 'Epinephrine measurement (procedure)', 'Adrenaline level', 'Adrenaline Measurement', 'ephinephrine level test', 'Epinephrine level']
# ['endo-(+/-)-alpha-(Hydroxymethyl)benzeneacetic Acid 8-methyl-8-azabicyclo[3.2.1]oct-3-yl Ester', '(±)-atropine', 'atropine', 'Atropine', 'Atropinum', 'Atropina', 'Benzeneacetic acid, alpha-(hydroxymethyl)- 8-methyl-8-azabicyclo(3.2.1)oct-3-yl ester endo-(+-)-', '(±)-hyoscyamine', 'Atropine-containing product', 'dl-Tropyl Tropate', 'dl-tropyltropate', 'dl-Hyoscyamine', 'Atropin', 'Atropine (substance)', 'ATROPINE', 'Tropine tropate', 'Product containing atropine (medicinal product)', 'atropine [chemical substance]', 'Dl-hyoscyamine']
# ['atropine [drug]', 'atropine']
# ['Atropines']
# ['atropine anabolism', 'atropine formation', 'atropine synthesis', 'atropine biosynthesis']
# ['Product containing homatropine (medicinal product)', 'HOMATROPINE', 'Omatropina', 'Homatropine (substance)', 'homatropine', '(3-endo)-8-Methyl-8-azabicyclo(3.2.1)oct-3-yl hydroxy(phenyl)acetate', 'Homatropine-containing product', 'Homatropina', 'Homatropine']
# ['Magnésium', 'mgs', 'Magnesium', 'MAGNESIUM', 'mg', 'Elemental Magnesium', 'Magnesio', 'Magnesium-containing product', 'magnesium', 'Magnesium, NOS', 'Mg', 'Magnesium (substance)', 'Magnesium metallicum', 'Mg element', 'Product containing magnesium (medicinal product)', 'Mg - Magnesium']
# ['Magnesium Measurement', 'Magnesium', 'magnesium measurement', 'magnesium level test', 'Magnesium level', 'Magnesium measurement', 'Magnesium measurement, NOS', 'Magnesium measurement (procedure)']
# ['Magnesium', 'Magnesium supplements, alimentary tract and metabolism']
# ['MAGNESIUM']
# ['Mg2+', 'Magnesium cation', 'Mg++ element', 'magnesium cation', 'Mn 2+', 'Magnesium Cation', 'MAGNESIUM CATION', 'Magnesium ion', 'magnesium ion', 'magnesium ions', 'Magnesium, ion(Mg2+)']
# ['bicarbonate of soda', 'Sodium bicarbonate (substance)', 'Baking soda', 'sodium hydrogen carbonate', 'Sodium Bicarbonate', 'Sodium hydrogencarbonate', 'Bicarbonate, Sodium', 'Sodium acid carbonate', 'Bicarbonate of soda', 'Carbonic acid monosodium salt', 'Bicarbonate of Soda', 'Product containing sodium bicarbonate (medicinal product)', 'Soda, Baking', 'Sodium bicarbonate-containing product', 'Sodium Hydrogen Carbonate', 'SODIUM BICARBONATE', 'baking soda', 'Sodium bicarbonate', 'bicarb', 'Sodio bicarbonato', 'sodium bicarbonate', 'bicarbs', 'Hydrogen Carbonate, Sodium', 'Sodium hydrogen carbonate', 'Baking Soda', 'NaHCO3', 'Carbonic Acid Monosodium Salt', 'Natriumhydrogenkarbonat', 'bicarbonates sodium']
# ['In addition to', 'Addition', 'Plus', 'W', 'PL', 'Cum', 'With (attribute)', 'With']
# ['Addition', 'Add']
# ['Add', 'Added', 'Additional']
# ['Additive', 'additive']
# []
# ['Both', 'Right and Left', 'Both sides', 'Bilateral', 'bilateral', 'BILATERAL', 'Right and left', 'both sides', 'Right and left (qualifier value)']
# ['Bilateral Cancer', 'Bilateral Malignant Tumor', 'Bilateral Malignant Neoplasm']
# ['Bilateral Carcinoma', 'Bilateral Cancer']
# []
# ['Thoracostomies, Needle', 'Thoracostomy, Needle', 'Needle Thoracostomies']
# ['Thoracostomies', 'thoracostomy', 'Thoracostomy', 'Thoracostomy, NOS']
# ['report [document]', 'report', 'Report (record artifact)', 'reports', 'Reports', 'Report', 'document report', 'Reported']
# ['informing', 'inform', 'Reporting', 'giving information', 'report', 'Informing (procedure)', 'Informing', 'reports', 'reported', 'reporting', 'Giving information', 'Reported']
# ['Report', 'Report:Find:Pt:{Setting}:Doc:{Role}', 'Report:Finding:To identify measures at a point in time:{Setting}:Document:{Role}']
# ['case reports', 'case report', 'case reported', 'case report [paper report]', 'Case Reports']
# ['Case Report', 'Case Studies', 'case study', 'Case report', 'Case Study', 'case studies']
# ['Air', 'Air (substance)', 'airs', 'Air, NOS', 'air']
# ['AI/RHEUM', 'AIR']
# ['AIR', 'ACUTE INSULIN RESPONSE']
# ['IGF2R antisense RNA 1 (non-protein coding)', 'ANTISENSE IGF2R RNA, NONCODING', 'NCRNA00088', 'AIR', 'AIRN gene', 'AIRN', 'IGF2R-AS1', 'antisense of IGF2R non-protein coding RNA', 'non-protein coding RNA 88', 'antisense of IGF2R RNA (non-protein coding)', 'ANTISENSE IGF2R RNA', 'IGF2RAS']
# ['Air', 'Air medicinal', 'AIR', 'Air, medicinal', 'medical air', 'Medical air', 'Medical air (medicinal product)', 'air']
# ['Lt - Left', 'Left side', 'left sided', 'left', 'left sides', 'Left', 'Left (qualifier value)', 'Left - Side', 'left side', 'Levo-']
# ['Left sided', 'Left-sided', 'left sided', 'Left sided (qualifier value)', 'Left', 'Left-Sided']
# ['left']
# ['Lower leg Left', 'Structure of left lower leg (body structure)', 'Leg Left', 'left legs', 'left leg', 'Structure of left lower leg', 'leg left', 'Left Leg', 'Left lower leg', 'Lower extremity.left>Lower leg', 'Leg-lower-left', 'Leg.left', 'lower left leg', 'Left leg']
# ['Both', 'Right and Left', 'Both sides', 'Bilateral', 'bilateral', 'BILATERAL', 'Right and left', 'both sides', 'Right and left (qualifier value)']
# ['Bilateral Cancer', 'Bilateral Malignant Tumor', 'Bilateral Malignant Neoplasm']
# ['Bilateral Carcinoma', 'Bilateral Cancer']
# []
# ['Minute', 'min', 'minute of time', 'Min', 'minute', 'minimum', 'minutes']
# ['Smaller', 'smaller', 'small', 'smalling', 'littles', 'Small', 'minute', 'little', 'Little', 'Small (qualifier value)', 'minutes']
# ['Minute', 'Minuscule (qualifier value)', 'Minuscule', 'minute', 'minutes']
# ['Minute', 'min', 'Arcminute', 'minute (qualifier value)', 'Minute Unit of Plane Angle', 'minute', 'minutes']
# ['per minute', '/min', 'minutes per', 'per minute (qualifier value)', '/minute', 'Per Minute']
# ['vecuronium', 'Vecuronio', 'Piperidinium, 1-((2Beta,3alpha,5alpha,16beta,17beta)-3,17-bis(acetyloxy)-2-(1-piperidinyl)androstan-16-yl)-1-methyl-', 'Vecuronium (substance)', 'VECURONIUM', 'Vecuronium-containing product', 'Vecuronium', 'Product containing vecuronium (medicinal product)']
# ['VECURONIUM BROMIDE', 'Bromide, Vecuronium', 'vecuronium bromide', 'Piperidinium, 1-((2beta,3alpha,5alpha,16beta,17beta)-3,17-bis(acetyloxy)-2-(1-piperidinyl)androstan-16-yl)-1-methyl-, bromide', 'Piperidinium, 1-((2beta,3alpha,5alpha,16beta,17beta)-3,17-bis(acetyloxy)-2-(1-piperidinyl)androstan-16-yl)-1-methyl-, Bromide', 'Vecuronium Hydrobromide', 'bromide vecuronium', 'Vecuronium bromide (substance)', 'Vecuronium Bromide', 'Vecuronium bromide', 'piperidinium, 1-((2beta,3alpha,5alpha,16beta,17beta)-3,17-bis(acetyloxy)-2-(1-piperidinyl)androstan-16-yl)-1-methyl-, bromide', 'Hydrobromide, Vecuronium']
# ['OGTT - Oral glucose tolerance test', 'glucose procedure testing tolerance', 'glucose challenge test', 'Glucose challenge test', 'glucose tolerance tests', 'GTT - Glucose tolerance test', 'Glucose tolerance test (procedure)', 'Glucose tolerance test, NOS', 'challenge glucose testing', 'glucose tests tolerance', 'glucose tolerance test', 'Glucose Tolerance Test', 'Glucose tolerance tests', 'gtts', 'Glucose tolerance test', 'gtt', 'glucose test tolerance', 'glucose testing tolerance', 'Glucose Tolerance Tests']
# ['Gestational trophoblastic neoplasia (morphologic abnormality)', 'Persistent trophoblastic disease', 'Neoplasia, Gestational Trophoblastic', 'Gestational Trophoblastic Neoplasms', 'trophoblastic tumor, gestational', 'Gestational trophoblastic neoplasia', 'Gestational trophoblastic neoplasm', 'Trophoblastic Neoplasm, Gestational', 'Gestational Trophoblastic Tumor', 'Neoplasms, Gestational Trophoblastic', 'gestational trophoblastic tumor', 'trophoblastic tumor GTT', 'Gestational trophoblastic tumor', 'Gestational trophoblastic neoplasia (disorder)', 'Gestational Trophoblastic Neoplasm', 'Neoplasm, Gestational Trophoblastic', 'Trophoblastic Neoplasia, Gestational', 'GTN', 'Persistent gestational trophoblastic disease', 'GTT', 'Gestational Trophoblastic Neoplasia', 'Trophoblastic Neoplasms, Gestational']
# ['asthmatics', 'asthmatic', 'ASTHMA', 'Bronchial asthma, NOS', 'Asthma', 'Asthma, Bronchial', 'Airway hyperreactivity', 'ASTHMA BRONCHIAL', 'ASTHMA, BRONCHIAL', 'Asthma, unspecified', 'asthma disorders', 'br asthma', 'Asthmas', 'Bronchial Asthma', 'Asthmatic', 'Bronchial asthma', 'asthma', 'Asthma (disorder)', 'Asthma, NOS', 'BRONCHIAL ASTHMA', 'bronchial asthma', 'bronchitic asthma']
# ['status asthmaticus', 'asthma asthmaticus status', 'asthmaticus status', 'Asthma, unspecified type, with status asthmaticus', 'STATUS ASTHMATICUS', 'Asthmatic Crises', 'Shock, Asthmatic', 'Status Asthmaticus', 'Asthmatic Shocks', 'Shocks, Asthmatic', 'Asthmatic Crisis', 'Status asthmaticus', 'Asthma with status asthmaticus', 'Asthmatic Shock', 'severe acute asthma', 'acute severe asthma', 'Acute severe exacerbation of asthma', 'Asthmaticus, Status', 'Acute severe exacerbation of asthma (disorder)', 'Crisis, Asthmatic', 'asthmatic crisis', 'Crises, Asthmatic', 'Acute severe asthma']
# ['cooling', 'Cool', 'Cooling']
# ['Body cooling', 'body cooling', 'Active cooling of patient (procedure)', 'body cool']
# ['cooler', 'cooling unit', 'coolers', 'Cooling Units', 'Coolers']
# ['Cooling System', 'Cooling Module']
# ['Hypothermia, Gastric', 'Gastric Lavages, Cold', 'Gastric freezing (procedure)', 'Gastric freezing', 'Lavage, Cold Gastric', 'Gastric cooling therapy', 'Cryotherapy of stomach', 'Cold Gastric Lavages', 'Gastric Lavage, Cold', 'Gastric cooling', 'Cold Gastric Lavage', 'Gastric cooling therapy (procedure)', 'Lavages, Cold Gastric', 'Gastric hypothermia']
# ['Protocols (qualifier value)', 'Protocols', 'Protocol', 'protocol', 'protocols', 'protocols documentation']
# ['DOC.REF.CTP', 'Clinical trial protocol document', 'Clinical Study Protocol', 'Clinical Trial Protocol reference document', 'Protocol', 'Study Protocol']
# ['Library Protocol', 'Protocol']
# ['Study Protocol', 'Protocol']
# ['Protocol']
# ['Surgical transfer - action', 'transfer', 'Transfer', 'surgical transfer', 'Transfer procedure', 'Surgical transfer - action (qualifier value)', 'transfered', 'Transfer - action', 'transferred']
# ['Transfer', 'Delivery', 'Transport', 'Transferred', 'Deliver', 'Transfer Technique', 'Delivered']
# ['patients transferred', 'patient transferring', 'Transfers, Patient', 'Patient Transfers', 'Patient transfer', 'PATIENT TRANSFERS', 'Patient Transfer', 'patient transfers', 'patients transfers', 'Transfer, Patient', 'Transfer care', 'Transfer of patient', 'patients transferring', 'patient transfer', 'Patient transfer (procedure)', 'patients transfer', 'Transfer of patient procedure']
# ['Transfer']
# ['ActClassTransfer', 'transfer']
# ['Evaluated', 'efficacy assessment', 'evaluation', 'evaluations', 'Investigation', 'Evaluation', 'Evaluate', 'effectiveness assessment']
# ['assessment', 'Evaluation - action', 'Evaluation procedure', 'Assessment', 'clinical investigation', 'evaluation', 'assessment procedure', 'Evaluation procedure (procedure)', 'Evaluation - action (qualifier value)', 'Investigations', 'Investigation', 'Evaluation', 'Patient evaluation - action', 'Assessment Procedures', 'assessments', 'Clinical evaluation']
# ['Evaluation']
# ['examinations mouth', 'oral examination', 'Oral examination (procedure)', 'oral examinations', 'Oral examination', 'Oral Examination', 'Examinations, Oral', 'examinations oral', 'Mouth--Examination', 'Examination of mouth', 'mouth examination', 'Oral Evaluation', 'Examination, Oral', 'Oral Examinations']
# ['evaluation/testing', 'evaluation testing', 'evaluation tests', 'evaluation test', 'test evaluation']
# ['patients', 'patient', 'Patient', 'Patient (person)', '*^patient', '^Patient', 'Patients']
# ['Patient']
# ['Patient']
# ['Patient']
# ['Patient']
# ['Admission to hospital', 'hospital admission', 'Hospital admission, NOS', 'HOSPITAL ADMISSIONS', 'admit', 'Hospital Admission', 'Admission', 'Admit', 'admitted hospital', 'admission to hospital', 'Hospital admission', 'Hospital Admissions', 'admission hospital', 'hospital admissions', 'admissions hospital', 'admissions', 'admission', 'Hospital admission (procedure)', 'admitted', 'admits', 'admitting']
# ['Admission', 'Admitted']
# []
# ['PIM Kinase Inhibitor LGH447', 'LGH 447', 'LGH447', 'PIM447', 'PIM-447', 'PIM 447', 'LGH-447', 'PIM kinase inhibitor LGH447']
# ['Dyspnea, NOS', 'BREATHLESSNESS', 'Difficulty breathing', 'Breathless', 'Dyspnoea', 'SHORTNESS OF BREATH', 'difficult breathing', 'Breath Shortness', 'BREATHING DIFFICULT', 'Shortness of breath dyspnea', 'sob', 'breathing difficulty', 'breathing shortness', 'shortness of breath', 'DIFFICULTY BREATHING', 'DYSPNEA', 'SOB - Shortness of breath', 'Breathlessness', 'breath shortness', 'SOB', 'respiratory difficulty', 'Shortness of Breath', 'shortness of breath (SOB)', 'BREATH SHORTNESS', 'Breathing difficulties', 'Dyspnea (finding)', 'SOB (SHORTNESS OF BREATH)', 'dyspnoea', 'Trouble breathing', 'Respiration difficult', 'DIB - Difficulty in breathing', 'breathlessness', 'tightness of breath', 'DYSPNOEA', 'breathing difficulties', 'dyspnea', 'Shortness of breath', 'Abnormal breathing', 'Dyspnea', 's.o.b.', 'breathless', 'Respiratory difficulties', 'Dyspnoea, NOS', 'Breathing difficulty', 'Difficulty breathing (finding)', 'Difficult to breathe']
# ['shortness of breath at rest', 'Rest Dyspnea', 'Shortness of breath at rest', 'Dyspneas, Rest', 'Dyspnea, Rest', 'Dyspnea at rest (finding)', 'shortness of breath rest', 'Dyspnoea at rest', 'Breathless - at rest', 'Dyspnea at rest', 'Dyspnea At Rest', 'Rest dyspnea', 'Dyspnea resting', 'breath rest shortness', 'Dyspnea^resting', 'Breathlessness at rest', 'SOBAR - Shortness of breath at rest']
# []
# []
# ['Shortness of breathing upon physical activity', 'Dyspnea on exertion', 'exertional dyspnoea', 'Dyspnea on effort', 'Dyspnoea on exertion', 'exertional dyspnea', 'Breathlessness on exertion', 'SOBOE - Shortness of breath on exertion', 'Exertional dyspnoea', 'doe', 'DYSPNEA, EXERTIONAL', 'Exertional breathlessness', 'exertion dyspnea', 'SHORTNESS OF BREATH (ON EXERTION)', 'Short of breath on exertion', 'DOE', 'Dyspnea on exertion (finding)', 'dyspnea on exertion', 'shortness of breath on exertion', 'shortness of breath during exercise', 'Dyspnea Exertional', 'dyspnea on exertion (DOE)', 'dyspnea exertional', 'Exertional dyspnea', 'Dyspnoea on effort', 'Dyspnea, exertional', 'short of breath on exertion', 'DYSPNEA (ON EXERTION)']
# ['diagnosing', 'Diagnosis (observable entity)', 'Diagnostic', 'diagnosis', 'diagnoses', 'diagnosed', '{Diagnosis}', 'diagnose', 'DIAGNOSIS', 'Diagnosed', 'diagnosis (DX)', 'Diagnosis', 'Diagnose', 'Diagnoses', 'Dx']
# []
# ['Missing Diagnosis', 'Diagnoses, Missed', 'Diagnoses, Missing', 'Missing Diagnoses', 'Diagnosis, Missing', 'Missed Diagnoses', 'Diagnosis, Missed']
# ['diagnosis']
# ['Diagnoses, Oral', 'Oral Diagnoses', 'Oral Diagnosis']
# ['Cap', 'Cap (physical object)']
# ['CTX/DOX/PRED', 'cyclophosphamide/doxorubicin/prednisone', 'CAP', 'Cyclophosphamide/Doxorubicin/Prednisone']
# ['Cisplatin/Cyclophosphamide/Doxorubicin', 'CDDP/CTX/DOX', 'CAP-II', 'CAP-I', 'PAC', 'CISCA chemotherapy protocol', 'CAP', 'CISCA-II', 'cisplatin/cyclophosphamide/doxorubicin', 'cisplatin,cyclophosphamide and doxorubicin']
# ['placental leucine aminopeptidase', 'LEUCYL-CYSTINYL AMINOPEPTIDASE', 'PLAP', 'INSULIN-RESPONSIVE AMINOPEPTIDASE, MOUSE, HOMOLOG OF', 'P-LAP', 'LNPEP gene', 'CAP', 'leucyl/cystinyl aminopeptidase', 'OXYTOCINASE', 'leucyl and cystinyl aminopeptidase', 'cystinyl aminopeptidase', 'LNPEP', 'LEUCINE AMINOPEPTIDASE OF PLACENTA', 'IRAP']
# ['serpin peptidase inhibitor, clade B (ovalbumin), member 6', 'PI6', 'cytoplasmic antiproteinase', 'PROTEASE INHIBITOR 6', 'SERPINB6 gene', 'serpin family B member 6', 'SPI3', 'SERPINB6', 'deafness, autosomal recessive 91', 'CAP', 'PTI', 'serine (or cysteine) proteinase inhibitor, clade B (ovalbumin), member 6', 'placental thrombin inhibitor', 'DFNB91', 'SPI3, MOUSE, HOMOLOG OF', 'PLACENTAL THROMBIN INHIBITOR', 'SERPIN PEPTIDASE INHIBITOR, CLADE B (OVALBUMIN), MEMBER 6']
# ['asthmatics', 'asthmatic', 'ASTHMA', 'Bronchial asthma, NOS', 'Asthma', 'Asthma, Bronchial', 'Airway hyperreactivity', 'ASTHMA BRONCHIAL', 'ASTHMA, BRONCHIAL', 'Asthma, unspecified', 'asthma disorders', 'br asthma', 'Asthmas', 'Bronchial Asthma', 'Asthmatic', 'Bronchial asthma', 'asthma', 'Asthma (disorder)', 'Asthma, NOS', 'BRONCHIAL ASTHMA', 'bronchial asthma', 'bronchitic asthma']
# ['status asthmaticus', 'asthma asthmaticus status', 'asthmaticus status', 'Asthma, unspecified type, with status asthmaticus', 'STATUS ASTHMATICUS', 'Asthmatic Crises', 'Shock, Asthmatic', 'Status Asthmaticus', 'Asthmatic Shocks', 'Shocks, Asthmatic', 'Asthmatic Crisis', 'Status asthmaticus', 'Asthma with status asthmaticus', 'Asthmatic Shock', 'severe acute asthma', 'acute severe asthma', 'Acute severe exacerbation of asthma', 'Asthmaticus, Status', 'Acute severe exacerbation of asthma (disorder)', 'Crisis, Asthmatic', 'asthmatic crisis', 'Crises, Asthmatic', 'Acute severe asthma']
# ['Treated by', 'Treated with', 'TW', 'Treated with (attribute)']
# ['Treat', 'Treatment', 'treated with', 'treating', 'Treated', 'Treating', 'treated']
# ['cyclophosphane', 'cyts', 'N,N-bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxazaphosphorin-2-amine 2-Oxide', '(RS)-Cyclophosphamide', '(+-)-Cyclophosphamide', 'Cyclophosphamide-containing product', 'Mitoxan', 'Cyclophospham', 'Cyclophosphane', 'Cyclophosphanum', 'CTX', 'Cyclophosphan', 'cyclophosphamide', '2H-1,3,2-oxazaphosphorin-2-amine, N,N-is(2-chloroethyl)tetrahydro-,2-oxide, monohydrate', 'Cyclophosphamide (substance)', 'CYT', 'Cyclophosphamide', '2-[Bis(2-chloroethylamino)]-tetrahydro-2H-1,3,2-oxazaphosphorine-2-oxide', 'Claphene', 'cyt', 'CPM', 'Ciclofosfamide', 'N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxazaphosphorin-2-amine 2-oxide', 'Cyclophosphamidum', 'Cytophosphane', '(-)-cyclophosphamide', 'Cyclophosphamid', '2H-1,3,2-oxazaphosphorin-2-amine, N,N-is(2-chloroethyl)tetrahydro-,2-oxide', 'Bis(2-chloroethyl)phosphoramide cyclic propanolamide ester', 'CYCLOPHOSPHAMIDE', 'Product containing cyclophosphamide (medicinal product)', 'Ciclofosfamida', 'N,N-Bis(2-chloroethyl)tetrahydro-2H-1,3,2-oxazaphosphorin-2-amine 2-Oxide', 'Syklofosfamid']
# ['Cerebrotendinous Xanthomatoses', 'Van Bogaert Scherer Epstein Disease', 'Cerebral cholesterinosis', 'Xanthomatoses, Cerebrotendinous', 'Cerebrotendinous Xanthomatosis', 'Van Bogaert-Scherer-Epstein Disease', 'CTX - Cerebrotendinous xanthomatosis', 'Cholestanolosis', 'CTX', 'CEREBROTENDINOUS XANTHOMATOSIS', 'Van Bogaert-Scherer-Epstein disease', 'CEREBRAL CHOLESTERINOSIS', 'Cerebrotendinous xanthomatosis syndrome', 'VON BOGAERT DISEASE', 'Bogaert-Scherer-Epstein Disease, Van', 'Cerebrotendinous cholesterinosis', 'Cerebrotendinous xanthomatosis', 'Cholestanol storage disease (disorder)', 'cerebrotendinous xanthomatosis', 'Cerebral Cholesterinoses', 'Disease, Van Bogaert-Scherer-Epstein', 'van Bogaert-Scherer-Epstein syndrome', 'Cerebral Cholesterinosis', 'Cholestanol storage disease', 'Xanthomatosis, Cerebrotendinous', 'Sterol 27-hydroxylase deficiency']
# ['CP27', 'cerebrotendinous xanthomatosis', 'CTX', 'CYP27A1 Gene', 'CYP27', 'cytochrome P450 family 27 subfamily A member 1', 'CYP27A1', 'CYTOCHROME P450, SUBFAMILY XXVIIA, POLYPEPTIDE 1', 'cytochrome P450, family 27, subfamily A, polypeptide 1', 'CYP27A1 gene', 'STEROL 27-HYDROXYLASE', 'cytochrome P450, subfamily XXVIIA (steroid 27-hydroxylase, cerebrotendinous xanthomatosis), polypeptide 1', 'Cytochrome P450, Family 27, Subfamily A, Polypeptide 1 Gene']
# ['CP27', 'CTX', 'CYP27', 'Cytochrome P450, Family 27, Subfamily A, Polypeptide 1 wt Allele', 'CYP27A1 wt Allele']
# ['C-Terminal Telopeptide Type 1 Collagen', 'C-Telopeptide', 'CTX', 'Collagen Type 1 Cross-linked C-Telopeptide', 'Cross-Linked C-Terminal Telopeptide of Type I Collagen', 'C-Terminal Telopeptide Type I Collagen', 'CTX-I', 'CTXI']
# ['Product containing azithromycin (medicinal product)', 'Azithromycin', '(2R,3S,4R,5R,8R,10R,11R,12S,13S,14R)-13-[(2,6-Dideoxy-3-C-methyl-3-O-methyl-alpha-L-ribo-hexopyranosyl)oxy]-2-ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-11-[(3,4,6-trideoxy-3-(dimethylamino)-beta-D-xylo-hexopyranosyl]oxy]-1-oxa-6-azacyclopentade', 'Azithromycin (substance)', '(2R,3S,4R,5R,8R,10R,11R,12S,13S,14R)-13-[(2,6-Dideoxy-3-C-methyl-3-O-methyl-alpha-L-ribo-hexopyranosyl)oxy]-2-ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-11-[(3,4,6-trideoxy-3-(dimethylamino)-beta-D-xylo-hexopyranosyl)oxy]-1-oxa-6-azacyclopentade', 'Azithromycine', 'AZITHROMYCIN', 'Azithromycin-containing product', '1-Oxa-6-azacyclopentadecan-15-one, 13-((2,6-dideoxy-3-C-methyl-3-O-methyl-alpha-L-ribo-hexopyranosyl)oxy)-2-ethyl-3,4,10-trihydroxy-3,5,6,8,10,12,14-heptamethyl-11-((3,4,6-trideoxy-3-(dimethylamino)-beta-D-xylo-hexopyranosyl)oxy)-, (2R-(2R*,3S*,4R*,5R*,8R*,10R*,11R*,12S*,13S*,14R*))-', 'N-methyl-11-aza-10-deoxy-10-dihydroerythromycin A', 'Azithromycinum', 'azythromycin', 'azithromycin', 'Azitromicina', 'Azythromycin']
# ['azithromycin dihydrate', 'Azithromycin dihydrate', 'Azithromycin dihydrate (substance)', 'Azithromycin Dihydrate', 'AZITHROMYCIN DIHYDRATE', 'Dihydrate, Azithromycin']
# ['Admission to hospital', 'hospital admission', 'Hospital admission, NOS', 'HOSPITAL ADMISSIONS', 'admit', 'Hospital Admission', 'Admission', 'Admit', 'admitted hospital', 'admission to hospital', 'Hospital admission', 'Hospital Admissions', 'admission hospital', 'hospital admissions', 'admissions hospital', 'admissions', 'admission', 'Hospital admission (procedure)', 'admitted', 'admits', 'admitting']
# ['pre admissions', 'Pre-admission (qualifier value)', 'Pre-admission', 'pre-admission', 'pre admission']
# ['Admission', 'Admitted']
# ['Admissions, Patient', 'patient admissions', 'patient admission', 'client admission', 'admission patients', 'Admission, Patient', 'Patient Admissions']
# ['WINTER', 'winter']
# ['Yellow Rockets', 'upland cress', 'vulgari, Barbarea', 'Rocket, Yellow', 'Cress, Winter', 'Yellow rocket', 'Winter Cress', 'Barbarea vulgaris', 'Rockets, Yellow', 'Barbarea vulgaris (organism)', 'Cresses, Winter', 'Barbarea vulgari', 'yellow rocket', 'Yellow Rocket', 'Winter Cresses']
# ['HFH11', 'PIG29', 'TGT3', 'Trident Gene', 'FKHL16', 'MPHOSPH2', 'Forkhead Box M1 wt Allele', 'FOXM1 wt Allele', 'MPP-2', 'MPP2', 'INS-1', 'FOXM1B', 'WIN', 'HNF-3', 'HFH-11', 'TRIDENT']
# ['acute asthma exacerbation', 'exacerbation of asthma', 'of asthma exacerbation', 'exacerbation asthma', 'Exacerbation of asthma (disorder)', 'Acute asthma', 'asthma exacerbation', 'asthma exacerbations', 'Exacerbation of asthma', 'Asthma attack', 'acute exacerbation of asthma']
# ['status asthmaticus', 'asthma asthmaticus status', 'asthmaticus status', 'Asthma, unspecified type, with status asthmaticus', 'STATUS ASTHMATICUS', 'Asthmatic Crises', 'Shock, Asthmatic', 'Status Asthmaticus', 'Asthmatic Shocks', 'Shocks, Asthmatic', 'Asthmatic Crisis', 'Status asthmaticus', 'Asthma with status asthmaticus', 'Asthmatic Shock', 'severe acute asthma', 'acute severe asthma', 'Acute severe exacerbation of asthma', 'Asthmaticus, Status', 'Acute severe exacerbation of asthma (disorder)', 'Crisis, Asthmatic', 'asthmatic crisis', 'Crises, Asthmatic', 'Acute severe asthma']
# []
# ['Male Impotence', 'Impotence, Male Sexual', 'Sexual Impotence, Male', 'male erectile disorder', 'Sexual impotence, NOS', 'dysfunctioning erectile', 'Difficulty getting an erection', 'Difficulty getting a full erection', 'Impotence', 'Erectile dysfunction (disorder)', 'erection dysfunction', 'Male Erectile Disorder', 'Erectile dysfunction', 'Erectile Dysfunction', 'Erectile abnormalities', 'Male erectile disorder', 'dysfunction erection', 'sexual impotence', 'erectile dysfunctions', 'Male Sexual Impotence', 'Failure of erection', 'impotent', 'dysfunction erectile', 'PENILE ERECTION IMPAIRMENT', 'impotence', 'Impotent', 'Abnormal erection', 'IMPOTENCE', 'Impotence, Male', 'Dysfunction, Erectile', 'Impotence, NOS', 'Sexual impotence', 'ED', 'erectile dysfunction']
# ['Emergency (DEEDS)', 'Emergency Department (DEEDS) variables', 'ED']
# ['arterial blood gase', 'Analysis of arterial blood gases and pH', 'Gases, arterial measurement', 'ABG - Arterial blood gas analysis', 'Analysis of arterial blood gases and pH (procedure)', 'Measurement of systemic arterial blood gases', 'Arterial blood gas analysis', 'analysis arterial blood gas', 'ABG', 'arterial blood gas', 'Blood gases, arterial measurement (procedure)', 'Arterial Blood Gas Measurement', 'Blood Gas Measurement', 'Analysis of arterial blood gas (oxygen saturation, pO2, pCO2, CO2, pH); rest only', 'Blood Gas Analysis', 'ABGs measurement', 'arterial blood gases', 'Arterial blood gases', 'Blood gases, arterial measurement', 'blood gas arterial', 'arterial blood gas analysis']
# ['A1BG', 'ALPHA-1-B-GLYCOPROTEIN', 'GAB', 'ABG', 'alpha-1-B glycoprotein', 'A1BG gene', 'A1B']
# ['Bypass, Aortocoronary', 'Coronary artery bypass grafting', 'coronary artery bypass graft', 'Vascular aortocoronary bypass', 'ACB graft', 'Aortocoronary bypass grafting', 'Coronary artery bypass graft', 'coronary bypass', 'Bypasses, Aortocoronary', 'Cardiac revascularization with bypass anastomosis', 'Cardiac revascularization with aortocoronary bypass anastomosis', 'Coronary artery bypass grafts (CABG)', 'Aortocoronary artery bypass graft (procedure)', 'Coronary bypass', 'Coronary Artery Bypass Graft', 'Coronary artery bypass', 'coronary artery bypass graft (GABG)', 'Bypass anastomosis for heart revascularization', 'Coronary Artery Bypass Grafting', 'CABG - Coronary artery bypass graft', 'CAB graft', 'Aortocoronary Bypasses', 'coronary bypass surgery', 'Coronary Artery Bypasses', 'Aortocoronary bypass for heart revascularization', 'Coronary artery bypass graft (CABG)', 'CORONARY ARTERY BYPASS', 'Cardiac revascularisation with bypass anastomosis', 'Coronary artery bypass grafting (procedure)', 'Cardiac revascularisation with aortocoronary bypass anastomosis', 'Artery Bypasses, Coronary', 'Aortocoronary artery bypass graft', 'Aortocoronary bypass for heart revascularization, NOS', 'Aorto-coronary artery bypass graft', 'CORONARY BYPASS', 'Artery Bypass, Coronary', 'Bypass, Coronary Artery', 'Cardiac revascularization with bypass anastomosis (procedure)', 'Aortocoronary Bypass', 'CBG - Coronary bypass graft', 'Coronary Artery Bypass Surgery', 'Bypass Surgery, Coronary Artery', 'Coronary artery bypass graft operations', 'Aortocoronary bypass for heart revascularisation', 'coronary artery bypass', 'Coronary artery bypass graft surgery', 'CABG', 'CAG - Coronary artery graft', 'Heart Bypass', 'Coronary Artery Bypass', 'coronary artery bypass surgery', 'Bypasses, Coronary Artery', 'aortocoronary bypass', 'Aortocoronary bypass for heart revascularization, not otherwise specified', 'Cardiac revascularization with bypass anastomosis, NOS']
# ['CTH', 'CSE', 'cystathionase (cystathionine gamma-lyase)', 'CYSTATHIONASE', 'CYSTATHIONINE GAMMA-LYASE', 'cystathionine gamma-lyase', 'CTH gene']
# ['CTH', 'VSIG2', 'CTX, XENOPUS, HOMOLOG-LIKE', 'CTXL', 'VSIG2 gene', 'V-set and immunoglobulin domain containing 2', 'V-SET AND IMMUNOGLOBULIN DOMAINS-CONTAINING PROTEIN 2']
# ['Adrenocorticotrophin', 'adrenocorticotrophic hormone', 'CCTROP', 'Hormone, Adrenocorticotropic', 'Adrenocorticotropic hormone', 'corticotropin, repository', 'corticotrophins', 'Adrenocorticotropin', 'corticotropins', 'adrenocorticotropin', 'Corticotrophin (1-39)', 'Adrenocorticotrophic hormone', 'ACTH', '1-39 ACTH', 'Corticotrophin', 'Corticotropin', 'adrenocorticotropic peptide', 'Hormone, Adrenocorticotrophic', 'corticotrophin', 'Corticotropin preparation', 'acth hormone', 'Adrenocorticotropic hormone (substance)', 'Adrenocorticotrophic Hormone', 'adrenocorticotropic hormone (ACTH)', 'Corticotropin (1-39)', 'adrenotrophin', 'Adrenocorticotropic Hormone', 'CORTICOTROPIN', 'ACTH preparation', 'adrenotropin', 'ACTH - Adrenocorticotrophic hormone', 'ACTH (1-39)', 'corticotropin', 'adrenocorticotropic hormone', 'Adrenocorticotropic hormone preparation', 'Adrenocorticotropic hormone (ACTH)', 'adrenotropic hormone']
# ['beta-endorphin', 'proopiomelanocortin', 'opiomelanocortin prepropeptide', 'LPH', 'NPP', 'adrenocorticotropin', 'PROOPIOMELANOCORTIN', 'ACTH', 'POMC Gene', 'MELANOCYTE-STIMULATING HORMONE', 'MSH', 'POMC gene', 'POC', 'Proopiomelanocortin (Adrenocorticotropin/ Beta-Lipotropin/ Alpha-Melanocyte Stimulating Hormone/ Beta-Melanocyte Stimulating Hormone/ Beta-Endorphin) Gene', 'PRO-ACTH-ENDORPHIN', 'MELANOTROPIN', 'POMC', 'LIPOTROPIN', 'beta-melanocyte stimulating hormone', 'alpha-melanocyte stimulating hormone', 'beta-lipotropin', 'adrenocorticotropic hormone', 'CLIP']
# ['NPP', 'POC', 'POMC wt Allele', 'ACTH', 'MSH', 'Proopiomelanocortin (Adrenocorticotropin/ Beta-Lipotropin/ Alpha-Melanocyte Stimulating Hormone/ Beta-Melanocyte Stimulating Hormone/ Beta-Endorphin) wt Allele', 'CLIP', 'LPH']
# ['Chest', 'regions thoracic', 'Thoraces', 'CHEST', 'thoracics', 'thorax', 'thoracic', 'Thorace', 'THORAX', 'area thoracic', 'Chests', 'Thoracic (qualifier value)', 'Thoracic structure', 'Thorax, NOS', 'chest', 'thoracic area', 'Thoracic', 'thoraces', 'Thorax', 'chest and upper back', 'Thoracic structure (body structure)', 'chest region', 'thoracic region']
# ['Chest', 'Subdivision of chest', 'Anterior thoracic region', 'Front of thorax', 'Chest region', 'Anterolateral part of thorax']
# ['Peas', 'Pea (substance)', 'peas', 'Pea', 'pea']
# ['electromechanical dissociation', 'Cardiac arrest with electromechanical dissociation', 'Electromechanical Dissociation by ECG Finding', 'Pulseless Electrical Activity', 'PEA - Pulseless electrical activity', 'emd', 'EMD', 'electromechanical dissociation (EMD)', 'Electro-Mechanical Dissociation', 'Electromechanical Dissociation by EKG Finding', 'Pulseless electrical activity', 'Electromechanical dissociation', 'PEA', 'pulseless electrical activity', 'Electromechanical dissociation (disorder)', 'Electromechanical Dissociation']
# ['garden pea', 'peas', 'Pisum sativum', 'sativum, Pisum', 'pea', 'pisum sativum']
# ['PEA']
# ['Pisum sativum allergenic extract', 'PEA', 'Pea', 'pea allergenic extract']
# ['arrest [as an cardiac arrest]', 'Cardiac arrest (disorder)', 'ARREST CARDIAC', 'Cardiac arrest- asystole', 'arrest', 'cardiac arrest', 'CARDIAC ASYSTOLE', 'ASYSTOLIA', 'Asystole (disorder)', 'ventricular asystole', 'Asystole', 'VENTRICULAR ASYSTOLIA', 'cardiac asystole', 'Heart Arrest', 'Arrest, Heart', 'asystolia', 'Arrest, Cardiac', 'SCA', 'Cardiac Arrest', 'Cardiac arrest', 'asystole', 'Heart stops beating', 'heart arrest', 'Asystoles', 'STANDSTILL CARDIAC', 'Cardiac standstill', 'ASYSTOLE', 'HEART ARREST', 'arrested', 'CARDIAC ARREST']
# ['Arrested', 'Arrest', 'Arrested (qualifier value)', 'Arresting']
# ['arrest', 'legal arrest', 'arrests', 'arresting']
# ['Arrester']
# ['S-Antigen, Retinal', 'Arrestin', 'Retinal S-Antigen', 'S Antigen, Retinal', 'Retinal S Antigen', 'arrestin']
# ['Minute', 'min', 'minute of time', 'Min', 'minute', 'minimum', 'minutes']
# ['Smaller', 'smaller', 'small', 'smalling', 'littles', 'Small', 'minute', 'little', 'Little', 'Small (qualifier value)', 'minutes']
# ['Minute', 'Minuscule (qualifier value)', 'Minuscule', 'minute', 'minutes']
# ['Minute', 'min', 'Arcminute', 'minute (qualifier value)', 'Minute Unit of Plane Angle', 'minute', 'minutes']
# ['per minute', '/min', 'minutes per', 'per minute (qualifier value)', '/minute', 'Per Minute']
# ['(-)-(R)-epinephrine', 'Product containing epinephrine (medicinal product)', '4-(1-Hydroxy-2-(methylamino)ethyl)-1,2-benzenediol', 'Epinephrinum', 'Therapeutic Epinephrine', 'epi', '(R)-(-)-adrenaline', 'therapeutic epinephrine', 'Adrenaline preparation', '(R)-(-)-Adnephrine', 'Adrenaline', 'Epinephrine', 'epinephrine', '(-)-3,4-dihydroxy-α-((methylamino)methyl)benzyl alcohol', '1,2-Benzenediol, 4-(1-hydroxy-2-(methylamino)ethyl)-, (R)-', 'Adrenaline-containing product', '(R)-(-)-Epinephrine', '(R)-(-)-Adrenaline', '(R)-(-)-Epirenamine', 'adrenalin', 'Adrenalin', 'Epinefrin', 'EPINEPHrine', 'adrenaline', 'EPINEPHRINE', 'Epinephrine-containing product', 'Adrénaline', '4-[(1R)-1-Hydroxy-2-(methylamino)ethyl]-1,2-benzenediol', 'Epinefrina', 'Epinephrine (substance)', 'Epinephrine preparation', 'Epinephrin']
# ['Magnetic Resonance Imaging, Echo Planar', 'Echo-Planar Imaging', 'Medical Imaging, Planar', 'Magnetic Resonance Imaging, Echo-Planar', 'Imaging, Echoplanar', 'Echoplanar Imaging', 'Imaging, Echo-Planar', 'Echo Planar Imaging', 'Magnetic Resonance Imaging, Echoplanar', 'Echoplanar Imagings', 'Echo-Planar Magnetic Resonance Imaging', 'echo-planar imaging', 'Echoplanar Magnetic Resonance Imaging', 'Imagings, Echoplanar', 'Imagings, Echo-Planar', 'Echo Planar Magnetic Resonance Imaging', 'EPI', 'echo planar imaging', 'Echo-Planar Imagings']
# ['Pancreatic exocrine insufficiency', 'Insufficiencies, Exocrine Pancreatic', 'Insufficiency, Exocrine Pancreatic', 'Exocrine Pancreatic Insufficiency', 'Pancreatic Insufficiency', 'Exocrine Pancreas Insufficiency', 'Exocrine pancreatic insufficiency (disorder)', 'Exocrine pancreatic insufficiency (EPI)', 'Pancreatic Insufficiencies, Exocrine', 'Exocrine pancreatic insufficiency', 'Insufficiency, Pancreatic', 'Pancreatic Insufficiencies', 'Pancreatic Insufficiency, Exocrine', 'Exocrine Pancreatic Insufficiencies', 'EPI', 'Inability to properly digest food due to lack of pancreatic digestive enzymes', 'Insufficiencies, Pancreatic']
# ['Eysenck Personality Inventory', 'EPI - Eysenck personality inventory', 'Eysenck personality inventory', 'EPI', 'eysenck personality inventory (EPI)', 'Eysenck personality inventory (assessment scale)']
# ['TFPI Gene', 'tissue factor pathway inhibitor', 'TFPI', 'LACI', 'EXTRINSIC PATHWAY INHIBITOR', 'LIPOPROTEIN-ASSOCIATED COAGULATION INHIBITOR', 'EPI', 'TISSUE FACTOR PATHWAY INHIBITOR', 'tissue factor pathway inhibitor (lipoprotein-associated coagulation inhibitor)', 'TFPI gene', 'TFI', 'TFPI1', 'extrinsic pathway inhibitor', 'Tissue Factor Pathway Inhibitor (Lipoprotein-Associated Coagulation Inhibitor) Gene']
# ['bicarbonate of soda', 'Sodium bicarbonate (substance)', 'Baking soda', 'sodium hydrogen carbonate', 'Sodium Bicarbonate', 'Sodium hydrogencarbonate', 'Bicarbonate, Sodium', 'Sodium acid carbonate', 'Bicarbonate of soda', 'Carbonic acid monosodium salt', 'Bicarbonate of Soda', 'Product containing sodium bicarbonate (medicinal product)', 'Soda, Baking', 'Sodium bicarbonate-containing product', 'Sodium Hydrogen Carbonate', 'SODIUM BICARBONATE', 'baking soda', 'Sodium bicarbonate', 'bicarb', 'Sodio bicarbonato', 'sodium bicarbonate', 'bicarbs', 'Hydrogen Carbonate, Sodium', 'Sodium hydrogen carbonate', 'Baking Soda', 'NaHCO3', 'Carbonic Acid Monosodium Salt', 'Natriumhydrogenkarbonat', 'bicarbonates sodium']
# ['Admission to hospital', 'hospital admission', 'Hospital admission, NOS', 'HOSPITAL ADMISSIONS', 'admit', 'Hospital Admission', 'Admission', 'Admit', 'admitted hospital', 'admission to hospital', 'Hospital admission', 'Hospital Admissions', 'admission hospital', 'hospital admissions', 'admissions hospital', 'admissions', 'admission', 'Hospital admission (procedure)', 'admitted', 'admits', 'admitting']
# ['Admission', 'Admitted']
# []
# ['administration [executive duty]', 'Administration, Management', 'Administration (navigational concept)', 'Management', 'Administration', 'administration']
# ['Management, Disease', 'management', 'Disease management', 'disease management', 'Disease Managements', 'Managements, Disease', 'Disease Management']
# ['Supervision', 'Management procedure', 'Managing', 'Oversight', 'management procedures', 'Management', 'management procedure', 'Managed', 'Management procedure (procedure)']
# ['Management', 'Management Occupations']
# ['Care management', 'care management']
# ['patients', 'patient', 'Patient', 'Patient (person)', '*^patient', '^Patient', 'Patients']
# ['Patient']
# ['Patient']
# ['Patient']
# ['Patient']
# []
# ['intubation', 'Intubation', 'Intubation (procedure)', 'Intubations', 'intubation procedures', 'intubation procedure', 'INTUBATION', 'Intubation Procedure', 'Intubation, NOS', 'intubations', 'Intubation - action', 'Intubation - action (qualifier value)']
# ['Under sedation', 'Sedated', 'sedation [status]', 'Sedated state', 'sedation', 'sedating', 'under sedation', 'sedates', 'sedate', 'Sedation', 'SEDATION', 'Sedated (finding)', 'sedated']
# ['Sedation procedure', 'sedation', 'Administration of sedative (procedure)', 'sedation [procedure]', 'Sedative therapy', 'Administration of sedative', 'Sedation', 'Sedation procedure, NOS', 'Sedation, NOS']

# %%
print(diagnosis_dict)
print(count_dict)
for key, val in count_dict.items():
    print(f"{key}: {ner_prediction(str(key), compute='cpu')['entity_group'].iloc[0]}: {val}" + '\n')
# Out:
# {Anoxic: [], Brain Injury: ['Brain Damage', 'cerebral injury', 'damage brain', 'brain injury tissue', 'brain injuries', 'brain lesion (from injury)', 'Brain damage, NOS', 'Cerebral damage', 'Brain Injuries', 'brain tissue injury', 'Brain damage', 'Brain Injury', 'injury brain', 'Injuries, Brain', 'cerebral damage', 'Acquired brain injury', 'disorder brain injury', 'Damage, brain', 'brain injury', 'Injury, Brain', 'brain disorders injury', 'brain damages', 'Brain injury', 'brain damage', 'Chronic Brain Injury', 'Chronic Brain Injuries', 'chronic brain injury', 'Brain Injuries, Chronic', 'Injury', 'Traumatic or non-traumatic injury (disorder)', 'Traumatic or non-traumatic injury', 'Trauma', 'Traumatic injury', 'Injury', 'injuries', 'Traumatic injury (disorder)', 'injury', 'Injury, NOS', 'Injury - disorder', 'TRAUMATIC INJURY', 'Injuries', 'INJURY', 'injury from an external force', 'Wound', 'Traumatic Injury'], PEA arrest x2: [], Status Asthmaticus: ['status asthmaticus', 'asthma asthmaticus status', 'asthmaticus status', 'Asthma, unspecified type, with status asthmaticus', 'STATUS ASTHMATICUS', 'Asthmatic Crises', 'Shock, Asthmatic', 'Status Asthmaticus', 'Asthmatic Shocks', 'Shocks, Asthmatic', 'Asthmatic Crisis', 'Status asthmaticus', 'Asthma with status asthmaticus', 'Asthmatic Shock', 'severe acute asthma', 'acute severe asthma', 'Acute severe exacerbation of asthma', 'Asthmaticus, Status', 'Acute severe exacerbation of asthma (disorder)', 'Crisis, Asthmatic', 'asthmatic crisis', 'Crises, Asthmatic', 'Acute severe asthma', 'Acute severe refractory exacerbation of asthma (disorder)', 'Status asthmaticus', 'Acute severe refractory exacerbation of asthma', 'Acute severe asthma', 'asthmatics', 'asthmatic', 'ASTHMA', 'Bronchial asthma, NOS', 'Asthma', 'Asthma, Bronchial', 'Airway hyperreactivity', 'ASTHMA BRONCHIAL', 'ASTHMA, BRONCHIAL', 'Asthma, unspecified', 'asthma disorders', 'br asthma', 'Asthmas', 'Bronchial Asthma', 'Asthmatic', 'Bronchial asthma', 'asthma', 'Asthma (disorder)', 'Asthma, NOS', 'BRONCHIAL ASTHMA', 'bronchial asthma', 'bronchitic asthma'], Ventilator: ['ventilators', 'ventilator', 'Ventilator equipment', 'Ventilators', 'Ventilator (physical object)', 'Ventilator equipment (physical object)', 'Ventilator', 'Ventilator', 'portable ventilators', 'care homes ventilator', 'Ventilators, Volume, Portable', 'portable ventilator', 'Household ventilator, device (physical object)', 'Home Care Ventilators', 'Household ventilator, device', 'Ventilators, Home Care, Portable', 'Ventilators', 'Portable Ventilators', 'Ventilators, Portable/Home Care', 'Ventilator', 'Ventilator care (regime/therapy)', 'Ventilator Care', 'ventilator care', 'care ventilator', 'ventilation', 'Ventilations', 'ventilations', 'environmental air flow', 'air ventilation', 'Ventilate', 'Ventilation'], Pneumonia: ['Lung inflamed', 'Pulmonitis', 'PNEUMONIA', 'Pneumonias', 'Pneumonia (disorder)', 'Pneumonia, NOS', 'Pneumonia', 'pneum', 'pulmonary inflammation', 'pneumonia', 'unspecified pneumonia', 'inflammation lungs', 'lung inflammation', 'Pulmonary inflammation', 'Pneumonitis, NOS', 'Pneumonias, Mycoplasma', 'Atypical Pneumonias, Primary', 'Primary Atypical Pneumonias', 'Pneumonia caused by Genus Mycoplasma (disorder)', 'Mycoplasma Pneumonias', 'Eaton agent pneumonia', 'Endemic pneumonia', 'mycoplasmas pneumonia', 'Mycoplasmal pneumonia', 'Pneumonia, Primary Atypical', 'Pneumonia caused by Mycoplasma pneumoniae', 'primary atypical pneumonia', "Pneumonia due to Eaton's agent", 'Mycoplasmal Pneumonia', 'cold agglutinin positive pneumonia', 'Pneumonias, Primary Atypical', 'Pneumonia due to mycoplasma pneumoniae', 'Pneumonia due to Mycoplasma pneumoniae', 'Primary atypical pneumonia due to Mycoplasma pneumoniae', 'mycoplasma pneumonia', 'PNEUMONIA, COLD AGGLUTININ POSITIVE', 'Pneumonia, Mycoplasma', 'PPLO', 'MYCOPLASMA PNEUMONIA', 'Mycoplasma Pneumonia', 'pneumonia mycoplasma', 'Atypical Pneumonia, Primary', 'Primary atypical pneumonia (PAP) due to mycopl ...
# {Anoxic: 0, Brain Injury: 0, PEA arrest x2: 0, Status Asthmaticus: 8, Ventilator: 0, Pneumonia: 0, Chronic Systolic Heart Failure: 0, L1 compression fracture: 0, Seizures: 0, hypoxic: 0}
# Anoxic: Sign_symptom: 0
#
# Brain Injury: Disease_disorder: 0
#
# PEA arrest x2: Disease_disorder: 0
#
# Status Asthmaticus: Diagnostic_procedure: 8
#
# Ventilator: Therapeutic_procedure: 0
#
# Pneumonia: Disease_disorder: 0
#
# Chronic Systolic Heart Failure: Detailed_description: 0
#
# L1 compression fracture: Sign_symptom: 0
#
# Seizures: Sign_symptom: 0
#
# hypoxic: Sign_symptom: 0
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
# /home/codespace/.python/current/lib/python3.10/site-packages/transformers/pipelines/token_classification.py:169: UserWarning: `grouped_entities` is deprecated and will be removed in version v5.0.0, defaulted to `aggregation_strategy="simple"` instead.
#   warnings.warn(
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:94: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = final_df.append(disease_df) # adding the disease_df to existing
# /home/codespace/.python/current/lib/python3.10/site-packages/Bio_Epidemiology_NER/bio_recognizer.py:100: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   master_df = master_df.append(final_df)
